# %%
import numpy as np
import time
import gym
import torch
import torch.nn as nn
import random
import queue
import matplotlib.pyplot as plt
import math
from IPython.display import clear_output
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %% [markdown]
# # Define Class

# %%
class Env():
    def __init__(self):
        self.env = gym.make('CarRacing-v0')
        self.reward_threshold = self.env.spec.reward_threshold

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()
        self.die = False
        img_rgb = self.env.reset()
        img_gray = self.rgb2gray(img_rgb)
        self.stack = [img_gray] * 4
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(8):
            img_rgb, reward, die, _ = self.env.step(action)
            # don't penalize "die state"
            if die:
                reward += 100
            # green penalty
            if np.mean(img_rgb[:, :, 1]) > 185.0:
                reward -= 0.05
            total_reward += reward
            # if no reward recently, end the episode
            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break
        img_gray = self.rgb2gray(img_rgb)
        self.stack.pop(0)
        self.stack.append(img_gray)
        assert len(self.stack) == 4
        return np.array(self.stack), total_reward, done, die

    def render(self):
        self.env.render()

    def close(self):
        self.env.close()
        
    @staticmethod
    def rgb2gray(rgb, norm=True):
        gray = np.dot(rgb[..., :], [0.299, 0.587, 0.114])
        if norm:
            # normalize
            gray = gray / 128. - 1.
        return gray

    @staticmethod
    def reward_memory():
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.cnn_base = nn.Sequential(  # input shape (4, 96, 96)
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),  # activation
            nn.Conv2d(8, 16, kernel_size=3, stride=2),  # (8, 47, 47)
            nn.ReLU(),  # activation
            nn.Conv2d(16, 32, kernel_size=3, stride=2),  # (16, 23, 23)
            nn.ReLU(),  # activation
            nn.Conv2d(32, 64, kernel_size=3, stride=2),  # (32, 11, 11)
            nn.ReLU(),  # activation
            nn.Conv2d(64, 128, kernel_size=3, stride=1),  # (64, 5, 5)
            nn.ReLU(),  # activation
            nn.Conv2d(128, 256, kernel_size=3, stride=1),  # (128, 3, 3)
            nn.ReLU(),  # activation
        )  # output shape (256, 1, 1)
        self.v = nn.Sequential(nn.Linear(256, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(256, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

    def forward(self, x):
        x = self.cnn_base(x)
        x = x.view(-1, 256)
        v = self.v(x)
        x = self.fc(x)
        alpha = self.alpha_head(x) + 1
        beta = self.beta_head(x) + 1

        return (alpha, beta), v


class Agent():
    def __init__(self):
        self.net = Net().float().to(device)

    def select_action(self, state):
        state = torch.from_numpy(state).float().to(device).unsqueeze(0)
        with torch.no_grad():
            alpha, beta = self.net(state)[0]
        action = alpha / (alpha + beta)

        action = action.squeeze().cpu().numpy()
        return action

    def load_param(self):
        self.net.load_state_dict(torch.load('param/expert.pkl'))

# %% [markdown]
# # Getting new trajectory

# %%
     
class Classifier(nn.Module):
    def __init__(self,ch=2):
        super(Classifier,self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=4,out_channels=ch*8,kernel_size=7),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*8,out_channels=ch*16,kernel_size=5,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*16,out_channels=ch*32,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*32,out_channels=ch*32,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*32,out_channels=ch*64,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*64,out_channels=ch*64,kernel_size=3,stride=2),
            torch.nn.ReLU()
        )
        self.v = torch.nn.Sequential(
            torch.nn.Linear(64*ch*1*1,256),
            torch.nn.ReLU()
        )
        self.fc = torch.nn.Linear(256,3)
        self.ch = ch
        
    def forward(self,x):
        x = self.layer1(x)
        x = x.view(x.size(0),-1)
        x = self.v(x)
        x = self.fc(x)
        
        x[:,0] = torch.tanh(x[:,0])
        x[:,1] = torch.sigmoid(x[:,1])
        x[:,2] = torch.sigmoid(x[:,2])
        return x

# %%
#model = torch.load('BC_model_copy.pt')
class ImgDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, index):
        x = self.X[index]
        y = self.Y[index]
        return x, y
model = Classifier().cuda()

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

agent = Agent()
agent.load_param()

#agent_env = Env()
env = Env()
agent_total_score = 0
total_score = 0
average_reward=0
reward_list = list()
agent_scores = []
scores = []

X = list()
Y = list()
#FirstIteration = 100
epoch = 1200
beta = 1
my_prob = list()
for i_ep in range(1,epoch+1):
    print(i_ep)
    #agent_score = 0
    score = 0
    #agent_state = agent_env.reset()
    state = env.reset()
    #action_take_turn = 0
    if i_ep == 1:
        beta = 1
        my_prob = ['expert']*math.floor((beta*100)) + ['dagger']*math.floor((1-beta)*100)
    if i_ep == 501:
        beta = 0.95
    if i_ep == 501 or i_ep == 1001 or i_ep == 1501:
        #steps_for_expert = math.floor(beta * 1000)
        my_prob = ['expert']*math.floor((beta*100)) + ['dagger']*math.floor((1-beta)*100)
        beta *= beta
    for t in range(1000):
        #   action = model(torch.tensor(state.reshape(1,4,96,96)).cuda().float())[0]
        #    action = action.cpu().detach().numpy()
        #elif action_take_turn > 0 or i_ep <= 100:
        #    action = agent.select_action(state)
        #    if action_take_turn > 0 :
        #        action_take_turn-=1
        choice = random.choice(my_prob)
        if choice == 'dagger':
            action = model(torch.tensor(state.reshape(1,4,96,96)).cuda().float())[0]
            action = action.cpu().detach().numpy()
        elif choice == 'expert':
            action = agent.select_action(state)
        state_, reward, done, die = env.step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
        
        #reward_list.append(reward)
        #if len(reward_list) == 10:
        #    tmp=0
        #    for i in reward_list:
        #        tmp+=i
        #    tmp/=10
        #    average_reward = tmp
        #    reward_list.pop(0)
        #print(average_reward)
        # time.sleep(0.05)
        env.render()
        score += reward
        state = state_
        
        #if average_reward < 10 and action_take_turn != 0:
        #        action_take_turn = 100
        X.append(state)
        Y.append(action)
        if done or die:
            break
            
    if i_ep == 500 or i_ep == 1000 or i: # Start training the dagger model
        env.close()
        train_x, val_x= X[:math.floor(len(X)*0.8)], X[math.floor(len(X)*0.8):]
        train_y, val_y= Y[:math.floor(len(Y)*0.8)], Y[math.floor(len(Y)*0.8):]
        batch_size = 128
        train_set = ImgDataset(train_x, train_y)
        val_set = ImgDataset(val_x, val_y)
        train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0)
        val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0)

        device = torch.device('cuda')
        for inputs, labels in train_loader:
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            
        loss = nn.MSELoss().cuda()
        optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)
        num_epoch = 30
        
    
        for epoch in range(num_epoch):
            epoch_start_time = time.time()
            train_loss = 0.0
            val_loss = 0.0

            model.train() # 確保 model 是在 train model (開啟 Dropout 等...)
            for i, data in enumerate(train_loader):
                optimizer.zero_grad() # 用 optimizer 將 model 參數的 gradient 歸零
                train_pred = model(data[0].cuda().float())
                batch_loss = loss(train_pred, data[1].cuda()).cuda() # 計算 loss （注意 prediction 跟 label 必須同時在 CPU 或是 GPU 上）
                batch_loss.backward() # 利用 back propagation 算出每個參數的 gradient
                optimizer.step() # 以 optimizer 用 gradient 更新參數值

                train_loss += batch_loss.item()

            model.eval()
            with torch.no_grad():
                for i, data in enumerate(val_loader):
                    val_pred = model(data[0].cuda().float())
                    batch_loss = loss(val_pred, data[1].cuda())
                    val_loss += batch_loss.item()

                #將結果 print 出來
                print('[%03d/%03d] %2.2f sec(s) Train Loss: %3.6f | Val loss: %3.6f' % \
                    (epoch + 1, num_epoch, time.time()-epoch_start_time, train_loss/train_set.__len__(), val_loss/val_set.__len__()))

            torch.save(model, 'dagger.pt')
            model = torch.load('dagger.pt')
    
    
    total_score += score
    scores.append(score)
    
    #clear_output(wait=True)

    print("Epoch: {}".format(i_ep))
    print('BC\tmean: {:.2f}\tvariance: {:.2f}'.format(np.array(scores).mean(), np.array(scores).std()))
    continue
    
    #plt.figure()
    #plt.hist(x=scores, bins='auto', color='#0504aa', alpha=0.7, rwidth=0.85)
    ##plt.grid(axis='y', alpha=0.75)
    #plt.xlim(200,1070)
    ##plt.xlabel('score')
    #plt.ylabel('count')
    #plt.title('BC model')
    
    #plt.show()    
env.close()
#agent_env.close()
# Out:
# 1
# Track generation: 1260..1579 -> 319-tiles track
# C:\Users\awds2588\anaconda3\lib\site-packages\pyglet\image\codecs\wic.py:289: UserWarning: [WinError -2147417850] 執行緒模式設定後就不能再變更它。
#   warnings.warn(str(err))
# Epoch: 1
# BC	mean: 892.98	variance: 0.00
# 2
# Track generation: 1156..1449 -> 293-tiles track
# Epoch: 2
# BC	mean: 959.94	variance: 66.96
# 3
# Track generation: 1145..1431 -> 286-tiles track
# Epoch: 3
# BC	mean: 767.39	variance: 277.75
# 4
# Track generation: 1037..1300 -> 263-tiles track
# Epoch: 4
# BC	mean: 835.91	variance: 268.23
# 5
# Track generation: 1004..1259 -> 255-tiles track
# Epoch: 5
# BC	mean: 851.26	variance: 241.86
# 6
# Track generation: 947..1195 -> 248-tiles track
# Epoch: 6
# BC	mean: 862.29	variance: 222.16
# 7
# Track generation: 1047..1313 -> 266-tiles track
# Epoch: 7
# BC	mean: 869.37	variance: 206.41
# 8
# Track generation: 1203..1516 -> 313-tiles track
# Epoch: 8
# BC	mean: 873.66	variance: 193.42
# 9
# Track generation: 1097..1375 -> 278-tiles track
# Epoch: 9
# BC	mean: 891.67	variance: 189.33
# 10
# Track generation: 1295..1623 -> 328-tiles track
# Epoch: 10
# BC	mean: 904.48	variance: 183.68
# 11
# Track generation: 1143..1433 -> 290-tiles track
# Epoch: 11
# BC	mean: 889.64	variance: 181.31
# 12
# Track generation: 1174..1472 -> 298-tiles track
# Epoch: 12
# BC	mean: 901.27	variance: 177.83
# 13
# Track generation: 1179..1478 -> 299-tiles track
# Epoch: 13
# BC	mean: 911.06	variance: 174.19
# 14
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 14
# BC	mean: 909.41	variance: 167.96
# 15
# Track generation: 1212..1519 -> 307-tiles track
# Epoch: 15
# BC	mean: 908.55	variance: 162.29
# 16
# Track generation: 1039..1305 -> 266-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Epoch: 16
# BC	mean: 908.97	variance: 157.15
# 17
# Track generation: 1267..1598 -> 331-tiles track
# Epoch: 17
# BC	mean: 907.75	variance: 152.53
# 18
# Track generation: 1207..1513 -> 306-tiles track
# Epoch: 18
# BC	mean: 906.81	variance: 148.29
# 19
# Track generation: 1125..1410 -> 285-tiles track
# Epoch: 19
# BC	mean: 913.49	variance: 147.09
# 20
# Track generation: 1240..1554 -> 314-tiles track
# Epoch: 20
# BC	mean: 913.06	variance: 143.38
# 21
# Track generation: 1178..1477 -> 299-tiles track
# Epoch: 21
# BC	mean: 912.44	variance: 139.95
# 22
# Track generation: 1035..1303 -> 268-tiles track
# Epoch: 22
# BC	mean: 912.34	variance: 136.73
# 23
# Track generation: 1196..1499 -> 303-tiles track
# Epoch: 23
# BC	mean: 911.82	variance: 133.75
# 24
# Track generation: 1043..1308 -> 265-tiles track
# Epoch: 24
# BC	mean: 911.94	variance: 130.93
# 25
# Track generation: 1030..1292 -> 262-tiles track
# Epoch: 25
# BC	mean: 916.84	variance: 130.51
# 26
# Track generation: 1068..1343 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 951..1201 -> 250-tiles track
# Epoch: 26
# BC	mean: 915.13	variance: 128.26
# 27
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 27
# BC	mean: 914.58	variance: 125.89
# 28
# Track generation: 1124..1419 -> 295-tiles track
# Epoch: 28
# BC	mean: 914.37	variance: 123.63
# 29
# Track generation: 1031..1295 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1180..1479 -> 299-tiles track
# Epoch: 29
# BC	mean: 913.85	variance: 121.51
# 30
# Track generation: 1208..1514 -> 306-tiles track
# Epoch: 30
# BC	mean: 917.43	variance: 121.02
# 31
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 31
# BC	mean: 917.03	variance: 119.07
# 32
# Track generation: 1283..1608 -> 325-tiles track
# Epoch: 32
# BC	mean: 916.28	variance: 117.27
# 33
# Track generation: 1082..1365 -> 283-tiles track
# Epoch: 33
# BC	mean: 919.70	variance: 117.09
# 34
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 34
# BC	mean: 919.04	variance: 115.42
# 35
# Track generation: 1168..1464 -> 296-tiles track
# Epoch: 35
# BC	mean: 922.17	variance: 115.21
# 36
# Track generation: 1063..1337 -> 274-tiles track
# Epoch: 36
# BC	mean: 925.11	variance: 114.92
# 37
# Track generation: 1051..1318 -> 267-tiles track
# Epoch: 37
# BC	mean: 928.18	variance: 114.85
# 38
# Track generation: 1283..1608 -> 325-tiles track
# Epoch: 38
# BC	mean: 927.22	variance: 113.48
# 39
# Track generation: 1068..1339 -> 271-tiles track
# Epoch: 39
# BC	mean: 926.27	variance: 112.17
# 40
# Track generation: 1299..1628 -> 329-tiles track
# Epoch: 40
# BC	mean: 928.51	variance: 111.63
# 41
# Track generation: 1099..1378 -> 279-tiles track
# Epoch: 41
# BC	mean: 931.04	variance: 111.42
# 42
# Track generation: 1075..1348 -> 273-tiles track
# Epoch: 42
# BC	mean: 930.82	variance: 110.09
# 43
# Track generation: 1199..1508 -> 309-tiles track
# Epoch: 43
# BC	mean: 932.85	variance: 109.60
# 44
# Track generation: 985..1244 -> 259-tiles track
# Epoch: 44
# BC	mean: 932.25	variance: 108.41
# 45
# Track generation: 1216..1524 -> 308-tiles track
# Epoch: 45
# BC	mean: 931.62	variance: 107.28
# 46
# Track generation: 1231..1543 -> 312-tiles track
# Epoch: 46
# BC	mean: 931.17	variance: 106.15
# 47
# Track generation: 1223..1533 -> 310-tiles track
# Epoch: 47
# BC	mean: 930.34	variance: 105.17
# 48
# Track generation: 996..1254 -> 258-tiles track
# Epoch: 48
# BC	mean: 932.50	variance: 105.12
# 49
# Track generation: 1231..1543 -> 312-tiles track
# Epoch: 49
# BC	mean: 922.33	variance: 125.68
# 50
# Track generation: 1188..1489 -> 301-tiles track
# Epoch: 50
# BC	mean: 922.21	variance: 124.41
# 51
# Track generation: 1054..1330 -> 276-tiles track
# Epoch: 51
# BC	mean: 921.44	variance: 123.31
# 52
# Track generation: 1197..1505 -> 308-tiles track
# Epoch: 52
# BC	mean: 923.30	variance: 122.84
# 53
# Track generation: 1180..1479 -> 299-tiles track
# Epoch: 53
# BC	mean: 922.83	variance: 121.72
# 54
# Track generation: 958..1206 -> 248-tiles track
# Epoch: 54
# BC	mean: 925.07	variance: 121.68
# 55
# Track generation: 1120..1404 -> 284-tiles track
# Epoch: 55
# BC	mean: 927.01	variance: 121.41
# 56
# Track generation: 1392..1744 -> 352-tiles track
# Epoch: 56
# BC	mean: 928.49	variance: 120.82
# 57
# Track generation: 1060..1329 -> 269-tiles track
# Epoch: 57
# BC	mean: 928.31	variance: 119.76
# 58
# Track generation: 1171..1475 -> 304-tiles track
# Epoch: 58
# BC	mean: 927.64	variance: 118.83
# 59
# Track generation: 1271..1593 -> 322-tiles track
# Epoch: 59
# BC	mean: 924.77	variance: 119.84
# 60
# Track generation: 1274..1597 -> 323-tiles track
# Epoch: 60
# BC	mean: 924.29	variance: 118.89
# 61
# Track generation: 1180..1479 -> 299-tiles track
# Epoch: 61
# BC	mean: 923.99	variance: 117.94
# 62
# Track generation: 1163..1456 -> 293-tiles track
# Epoch: 62
# BC	mean: 923.75	variance: 117.00
# 63
# Track generation: 1010..1273 -> 263-tiles track
# Epoch: 63
# BC	mean: 925.46	variance: 116.85
# 64
# Track generation: 976..1224 -> 248-tiles track
# Epoch: 64
# BC	mean: 925.08	variance: 115.97
# 65
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 65
# BC	mean: 924.97	variance: 115.08
# 66
# Track generation: 1159..1453 -> 294-tiles track
# Epoch: 66
# BC	mean: 924.58	variance: 114.25
# 67
# Track generation: 1119..1403 -> 284-tiles track
# Epoch: 67
# BC	mean: 926.05	variance: 114.02
# 68
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 68
# BC	mean: 927.56	variance: 113.85
# 69
# Track generation: 1024..1281 -> 257-tiles track
# Epoch: 69
# BC	mean: 927.21	variance: 113.06
# 70
# Track generation: 1068..1339 -> 271-tiles track
# Epoch: 70
# BC	mean: 927.03	variance: 112.26
# 71
# Track generation: 1167..1463 -> 296-tiles track
# Epoch: 71
# BC	mean: 926.54	variance: 111.54
# 72
# Track generation: 1119..1403 -> 284-tiles track
# Epoch: 72
# BC	mean: 927.99	variance: 111.44
# 73
# Track generation: 1091..1368 -> 277-tiles track
# Epoch: 73
# BC	mean: 927.68	variance: 110.70
# 74
# Track generation: 1155..1448 -> 293-tiles track
# Epoch: 74
# BC	mean: 927.20	variance: 110.03
# 75
# Track generation: 992..1244 -> 252-tiles track
# Epoch: 75
# BC	mean: 928.65	variance: 110.00
# 76
# Track generation: 1244..1567 -> 323-tiles track
# Epoch: 76
# BC	mean: 929.30	variance: 109.42
# 77
# Track generation: 1127..1413 -> 286-tiles track
# Epoch: 77
# BC	mean: 930.59	variance: 109.28
# 78
# Track generation: 1190..1491 -> 301-tiles track
# Epoch: 78
# BC	mean: 930.07	variance: 108.68
# 79
# Track generation: 1292..1619 -> 327-tiles track
# Epoch: 79
# BC	mean: 929.55	variance: 108.08
# 80
# Track generation: 1344..1684 -> 340-tiles track
# Epoch: 80
# BC	mean: 929.03	variance: 107.51
# 81
# Track generation: 1117..1400 -> 283-tiles track
# Epoch: 81
# BC	mean: 928.77	variance: 106.86
# 82
# Track generation: 983..1236 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1143..1435 -> 292-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 985..1235 -> 250-tiles track
# Epoch: 82
# BC	mean: 928.69	variance: 106.21
# 83
# Track generation: 1135..1426 -> 291-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1380..1728 -> 348-tiles track
# Epoch: 83
# BC	mean: 929.56	variance: 105.87
# 84
# Track generation: 1303..1633 -> 330-tiles track
# Epoch: 84
# BC	mean: 930.62	variance: 105.67
# 85
# Track generation: 1252..1569 -> 317-tiles track
# Epoch: 85
# BC	mean: 930.29	variance: 105.09
# 86
# Track generation: 1048..1314 -> 266-tiles track
# Epoch: 86
# BC	mean: 931.50	variance: 105.08
# 87
# Track generation: 1033..1301 -> 268-tiles track
# Epoch: 87
# BC	mean: 931.18	variance: 104.51
# 88
# Track generation: 1165..1467 -> 302-tiles track
# Epoch: 88
# BC	mean: 932.21	variance: 104.37
# 89
# Track generation: 1102..1381 -> 279-tiles track
# Epoch: 89
# BC	mean: 933.31	variance: 104.29
# 90
# Track generation: 1117..1400 -> 283-tiles track
# Epoch: 90
# BC	mean: 934.40	variance: 104.21
# 91
# Track generation: 1018..1276 -> 258-tiles track
# Epoch: 91
# BC	mean: 934.15	variance: 103.66
# 92
# Track generation: 911..1152 -> 241-tiles track
# Epoch: 92
# BC	mean: 935.30	variance: 103.68
# 93
# Track generation: 1097..1384 -> 287-tiles track
# Epoch: 93
# BC	mean: 934.89	variance: 103.19
# 94
# Track generation: 1149..1440 -> 291-tiles track
# Epoch: 94
# BC	mean: 934.38	variance: 102.76
# 95
# Track generation: 1122..1407 -> 285-tiles track
# Epoch: 95
# BC	mean: 935.41	variance: 102.70
# 96
# Track generation: 1287..1613 -> 326-tiles track
# Epoch: 96
# BC	mean: 931.69	variance: 108.41
# 97
# Track generation: 1084..1359 -> 275-tiles track
# Epoch: 97
# BC	mean: 931.44	variance: 107.88
# 98
# Track generation: 1187..1488 -> 301-tiles track
# Epoch: 98
# BC	mean: 931.08	variance: 107.39
# 99
# Track generation: 1089..1371 -> 282-tiles track
# Epoch: 99
# BC	mean: 930.61	variance: 106.94
# 100
# Track generation: 1212..1519 -> 307-tiles track
# Epoch: 100
# BC	mean: 930.28	variance: 106.46
# 101
# Track generation: 1219..1528 -> 309-tiles track
# Epoch: 101
# BC	mean: 931.20	variance: 106.33
# 102
# Track generation: 1288..1614 -> 326-tiles track
# Epoch: 102
# BC	mean: 932.04	variance: 106.14
# 103
# Track generation: 1170..1467 -> 297-tiles track
# Epoch: 103
# BC	mean: 931.41	variance: 105.82
# 104
# Track generation: 1077..1351 -> 274-tiles track
# Epoch: 104
# BC	mean: 932.37	variance: 105.76
# 105
# Track generation: 1160..1454 -> 294-tiles track
# Epoch: 105
# BC	mean: 932.17	variance: 105.28
# 106
# Track generation: 1179..1478 -> 299-tiles track
# Epoch: 106
# BC	mean: 933.02	variance: 105.15
# 107
# Track generation: 1040..1312 -> 272-tiles track
# Epoch: 107
# BC	mean: 933.96	variance: 105.10
# 108
# Track generation: 1171..1468 -> 297-tiles track
# Epoch: 108
# BC	mean: 934.82	variance: 104.99
# 109
# Track generation: 1320..1654 -> 334-tiles track
# Epoch: 109
# BC	mean: 934.29	variance: 104.65
# 110
# Track generation: 1105..1388 -> 283-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1156..1449 -> 293-tiles track
# Epoch: 110
# BC	mean: 934.04	variance: 104.20
# 111
# Track generation: 1078..1352 -> 274-tiles track
# Epoch: 111
# BC	mean: 934.98	variance: 104.20
# 112
# Track generation: 1090..1396 -> 306-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1140..1429 -> 289-tiles track
# Epoch: 112
# BC	mean: 934.66	variance: 103.79
# 113
# Track generation: 989..1246 -> 257-tiles track
# Epoch: 113
# BC	mean: 935.52	variance: 103.73
# 114
# Track generation: 1227..1548 -> 321-tiles track
# Epoch: 114
# BC	mean: 936.22	variance: 103.54
# 115
# Track generation: 1338..1677 -> 339-tiles track
# Epoch: 115
# BC	mean: 936.85	variance: 103.31
# 116
# Track generation: 1116..1408 -> 292-tiles track
# Epoch: 116
# BC	mean: 937.56	variance: 103.14
# 117
# Track generation: 1429..1798 -> 369-tiles track
# Epoch: 117
# BC	mean: 937.80	variance: 102.73
# 118
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 118
# BC	mean: 938.64	variance: 102.70
# 119
# Track generation: 1280..1604 -> 324-tiles track
# Epoch: 119
# BC	mean: 938.01	variance: 102.49
# 120
# Track generation: 1107..1396 -> 289-tiles track
# Epoch: 120
# BC	mean: 937.75	variance: 102.10
# 121
# Track generation: 1340..1679 -> 339-tiles track
# Epoch: 121
# BC	mean: 936.22	variance: 103.05
# 122
# Track generation: 1399..1753 -> 354-tiles track
# Epoch: 122
# BC	mean: 936.68	variance: 102.75
# 123
# Track generation: 1177..1475 -> 298-tiles track
# Epoch: 123
# BC	mean: 936.33	variance: 102.40
# 124
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 124
# BC	mean: 937.01	variance: 102.27
# 125
# Track generation: 1399..1753 -> 354-tiles track
# Epoch: 125
# BC	mean: 937.36	variance: 101.93
# 126
# Track generation: 1243..1558 -> 315-tiles track
# Epoch: 126
# BC	mean: 936.98	variance: 101.61
# 127
# Track generation: 960..1209 -> 249-tiles track
# Epoch: 127
# BC	mean: 937.80	variance: 101.63
# 128
# Track generation: 1171..1468 -> 297-tiles track
# Epoch: 128
# BC	mean: 938.46	variance: 101.50
# 129
# Track generation: 1151..1443 -> 292-tiles track
# Epoch: 129
# BC	mean: 938.16	variance: 101.16
# 130
# Track generation: 1000..1260 -> 260-tiles track
# Epoch: 130
# BC	mean: 938.07	variance: 100.78
# 131
# Track generation: 1132..1419 -> 287-tiles track
# Epoch: 131
# BC	mean: 937.72	variance: 100.47
# 132
# Track generation: 1118..1406 -> 288-tiles track
# Epoch: 132
# BC	mean: 937.42	variance: 100.15
# 133
# Track generation: 1041..1309 -> 268-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1051..1317 -> 266-tiles track
# Epoch: 133
# BC	mean: 938.12	variance: 100.11
# 134
# Track generation: 1167..1463 -> 296-tiles track
# Epoch: 134
# BC	mean: 938.77	variance: 100.01
# 135
# Track generation: 957..1207 -> 250-tiles track
# Epoch: 135
# BC	mean: 939.52	variance: 100.02
# 136
# Track generation: 1145..1444 -> 299-tiles track
# Epoch: 136
# BC	mean: 939.26	variance: 99.70
# 137
# Track generation: 1368..1714 -> 346-tiles track
# Epoch: 137
# BC	mean: 939.61	variance: 99.42
# 138
# Track generation: 1105..1395 -> 290-tiles track
# Epoch: 138
# BC	mean: 938.98	variance: 99.33
# 139
# Track generation: 1088..1374 -> 286-tiles track
# Epoch: 139
# BC	mean: 938.74	variance: 99.02
# 140
# Track generation: 1106..1396 -> 290-tiles track
# Epoch: 140
# BC	mean: 939.39	variance: 98.96
# 141
# Track generation: 1186..1487 -> 301-tiles track
# Epoch: 141
# BC	mean: 939.10	variance: 98.67
# 142
# Track generation: 1032..1294 -> 262-tiles track
# Epoch: 142
# BC	mean: 938.92	variance: 98.34
# 143
# Track generation: 1187..1496 -> 309-tiles track
# Epoch: 143
# BC	mean: 938.66	variance: 98.05
# 144
# Track generation: 1156..1458 -> 302-tiles track
# Epoch: 144
# BC	mean: 939.25	variance: 97.97
# 145
# Track generation: 1131..1423 -> 292-tiles track
# Epoch: 145
# BC	mean: 939.86	variance: 97.90
# 146
# Track generation: 1241..1555 -> 314-tiles track
# Epoch: 146
# BC	mean: 940.44	variance: 97.81
# 147
# Track generation: 1191..1493 -> 302-tiles track
# Epoch: 147
# BC	mean: 941.02	variance: 97.73
# 148
# Track generation: 1156..1449 -> 293-tiles track
# Epoch: 148
# BC	mean: 941.61	variance: 97.66
# 149
# Track generation: 1124..1409 -> 285-tiles track
# Epoch: 149
# BC	mean: 941.36	variance: 97.38
# 150
# Track generation: 1040..1308 -> 268-tiles track
# Epoch: 150
# BC	mean: 941.95	variance: 97.32
# 151
# Track generation: 1304..1634 -> 330-tiles track
# Epoch: 151
# BC	mean: 942.43	variance: 97.18
# 152
# Track generation: 1071..1343 -> 272-tiles track
# Epoch: 152
# BC	mean: 943.03	variance: 97.14
# 153
# Track generation: 1226..1537 -> 311-tiles track
# Epoch: 153
# BC	mean: 942.67	variance: 96.93
# 154
# Track generation: 1054..1322 -> 268-tiles track
# Epoch: 154
# BC	mean: 943.26	variance: 96.89
# 155
# Track generation: 1212..1526 -> 314-tiles track
# Epoch: 155
# BC	mean: 942.94	variance: 96.66
# 156
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 156
# BC	mean: 943.52	variance: 96.62
# 157
# Track generation: 1103..1383 -> 280-tiles track
# Epoch: 157
# BC	mean: 943.36	variance: 96.33
# 158
# Track generation: 1173..1478 -> 305-tiles track
# Epoch: 158
# BC	mean: 943.08	variance: 96.09
# 159
# Track generation: 1077..1355 -> 278-tiles track
# Epoch: 159
# BC	mean: 942.78	variance: 95.86
# 160
# Track generation: 1081..1362 -> 281-tiles track
# Epoch: 160
# BC	mean: 943.30	variance: 95.79
# 161
# Track generation: 1092..1369 -> 277-tiles track
# Epoch: 161
# BC	mean: 943.02	variance: 95.56
# 162
# Track generation: 1159..1453 -> 294-tiles track
# Epoch: 162
# BC	mean: 942.71	variance: 95.34
# 163
# Track generation: 1179..1478 -> 299-tiles track
# Epoch: 163
# BC	mean: 943.21	variance: 95.27
# 164
# Track generation: 1049..1315 -> 266-tiles track
# Epoch: 164
# BC	mean: 943.80	variance: 95.27
# 165
# Track generation: 1249..1573 -> 324-tiles track
# Epoch: 165
# BC	mean: 943.48	variance: 95.07
# 166
# Track generation: 1146..1440 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1387..1738 -> 351-tiles track
# Epoch: 166
# BC	mean: 942.43	variance: 95.74
# 167
# Track generation: 1140..1429 -> 289-tiles track
# Epoch: 167
# BC	mean: 942.96	variance: 95.70
# 168
# Track generation: 1105..1390 -> 285-tiles track
# Epoch: 168
# BC	mean: 943.49	variance: 95.65
# 169
# Track generation: 1139..1428 -> 289-tiles track
# Epoch: 169
# BC	mean: 943.17	variance: 95.46
# 170
# Track generation: 1213..1519 -> 306-tiles track
# Epoch: 170
# BC	mean: 942.87	variance: 95.26
# 171
# Track generation: 1325..1659 -> 334-tiles track
# Epoch: 171
# BC	mean: 943.03	variance: 95.00
# 172
# Track generation: 1224..1534 -> 310-tiles track
# Epoch: 172
# BC	mean: 942.79	variance: 94.78
# 173
# Track generation: 1180..1479 -> 299-tiles track
# Epoch: 173
# BC	mean: 943.26	variance: 94.71
# 174
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 174
# BC	mean: 942.96	variance: 94.52
# 175
# Track generation: 1140..1429 -> 289-tiles track
# Epoch: 175
# BC	mean: 943.50	variance: 94.52
# 176
# Track generation: 1103..1383 -> 280-tiles track
# Epoch: 176
# BC	mean: 943.25	variance: 94.31
# 177
# Track generation: 1159..1455 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1077..1350 -> 273-tiles track
# Epoch: 177
# BC	mean: 943.07	variance: 94.07
# 178
# Track generation: 1182..1482 -> 300-tiles track
# Epoch: 178
# BC	mean: 943.55	variance: 94.02
# 179
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 179
# BC	mean: 943.34	variance: 93.80
# 180
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 180
# BC	mean: 943.19	variance: 93.56
# 181
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 181
# BC	mean: 942.99	variance: 93.34
# 182
# Track generation: 948..1189 -> 241-tiles track
# Epoch: 182
# BC	mean: 942.82	variance: 93.11
# 183
# Track generation: 1012..1278 -> 266-tiles track
# Epoch: 183
# BC	mean: 943.30	variance: 93.09
# 184
# Track generation: 1011..1274 -> 263-tiles track
# Epoch: 184
# BC	mean: 943.78	variance: 93.06
# 185
# Track generation: 1143..1434 -> 291-tiles track
# Epoch: 185
# BC	mean: 944.24	variance: 93.02
# 186
# Track generation: 1115..1398 -> 283-tiles track
# Epoch: 186
# BC	mean: 944.72	variance: 93.00
# 187
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 187
# BC	mean: 944.52	variance: 92.79
# 188
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 188
# BC	mean: 944.98	variance: 92.76
# 189
# Track generation: 1144..1434 -> 290-tiles track
# Epoch: 189
# BC	mean: 944.73	variance: 92.57
# 190
# Track generation: 1292..1619 -> 327-tiles track
# Epoch: 190
# BC	mean: 944.48	variance: 92.40
# 191
# Track generation: 1196..1499 -> 303-tiles track
# Epoch: 191
# BC	mean: 944.24	variance: 92.21
# 192
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 192
# BC	mean: 944.66	variance: 92.15
# 193
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 193
# BC	mean: 944.47	variance: 91.95
# 194
# Track generation: 1199..1503 -> 304-tiles track
# Epoch: 194
# BC	mean: 944.18	variance: 91.80
# 195
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 195
# BC	mean: 944.62	variance: 91.76
# 196
# Track generation: 1192..1494 -> 302-tiles track
# Epoch: 196
# BC	mean: 945.05	variance: 91.73
# 197
# Track generation: 1080..1354 -> 274-tiles track
# Epoch: 197
# BC	mean: 944.92	variance: 91.51
# 198
# Track generation: 1144..1434 -> 290-tiles track
# Epoch: 198
# BC	mean: 944.73	variance: 91.32
# 199
# Track generation: 1052..1319 -> 267-tiles track
# Epoch: 199
# BC	mean: 944.59	variance: 91.11
# 200
# Track generation: 1163..1464 -> 301-tiles track
# Epoch: 200
# BC	mean: 944.98	variance: 91.05
# 201
# Track generation: 1151..1443 -> 292-tiles track
# Epoch: 201
# BC	mean: 944.81	variance: 90.85
# 202
# Track generation: 1123..1408 -> 285-tiles track
# Epoch: 202
# BC	mean: 945.23	variance: 90.82
# 203
# Track generation: 1111..1393 -> 282-tiles track
# Epoch: 203
# BC	mean: 945.67	variance: 90.81
# 204
# Track generation: 918..1155 -> 237-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 998..1252 -> 254-tiles track
# Epoch: 204
# BC	mean: 946.12	variance: 90.82
# 205
# Track generation: 1260..1579 -> 319-tiles track
# Epoch: 205
# BC	mean: 945.80	variance: 90.72
# 206
# Track generation: 995..1249 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1162..1457 -> 295-tiles track
# Epoch: 206
# BC	mean: 945.60	variance: 90.54
# 207
# Track generation: 1031..1292 -> 261-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1050..1351 -> 301-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1062..1335 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1216..1523 -> 307-tiles track
# Epoch: 207
# BC	mean: 945.97	variance: 90.48
# 208
# Track generation: 1076..1349 -> 273-tiles track
# Epoch: 208
# BC	mean: 946.39	variance: 90.47
# 209
# Track generation: 1291..1618 -> 327-tiles track
# Epoch: 209
# BC	mean: 946.06	variance: 90.38
# 210
# Track generation: 1168..1464 -> 296-tiles track
# Epoch: 210
# BC	mean: 946.42	variance: 90.31
# 211
# Track generation: 1016..1278 -> 262-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1168..1464 -> 296-tiles track
# Epoch: 211
# BC	mean: 946.12	variance: 90.20
# 212
# Track generation: 1030..1297 -> 267-tiles track
# Epoch: 212
# BC	mean: 946.55	variance: 90.22
# 213
# Track generation: 1130..1417 -> 287-tiles track
# Epoch: 213
# BC	mean: 946.93	variance: 90.17
# 214
# Track generation: 1124..1417 -> 293-tiles track
# Epoch: 214
# BC	mean: 946.71	variance: 90.01
# 215
# Track generation: 1094..1372 -> 278-tiles track
# Epoch: 215
# BC	mean: 947.12	variance: 90.00
# 216
# Track generation: 945..1190 -> 245-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1111..1393 -> 282-tiles track
# Epoch: 216
# BC	mean: 946.92	variance: 89.84
# 217
# Track generation: 1224..1534 -> 310-tiles track
# Epoch: 217
# BC	mean: 947.26	variance: 89.77
# 218
# Track generation: 1133..1423 -> 290-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1384..1734 -> 350-tiles track
# Epoch: 218
# BC	mean: 947.56	variance: 89.67
# 219
# Track generation: 1211..1518 -> 307-tiles track
# Epoch: 219
# BC	mean: 947.91	variance: 89.62
# 220
# Track generation: 1155..1447 -> 292-tiles track
# Epoch: 220
# BC	mean: 947.65	variance: 89.50
# 221
# Track generation: 1159..1455 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1172..1469 -> 297-tiles track
# Epoch: 221
# BC	mean: 947.41	variance: 89.37
# 222
# Track generation: 1235..1548 -> 313-tiles track
# Epoch: 222
# BC	mean: 947.71	variance: 89.28
# 223
# Track generation: 1126..1420 -> 294-tiles track
# Epoch: 223
# BC	mean: 947.50	variance: 89.14
# 224
# Track generation: 1152..1444 -> 292-tiles track
# Epoch: 224
# BC	mean: 947.23	variance: 89.03
# 225
# Track generation: 1051..1318 -> 267-tiles track
# Epoch: 225
# BC	mean: 947.61	variance: 89.02
# 226
# Track generation: 1083..1367 -> 284-tiles track
# Epoch: 226
# BC	mean: 947.98	variance: 88.99
# 227
# Track generation: 1307..1638 -> 331-tiles track
# Epoch: 227
# BC	mean: 948.29	variance: 88.91
# 228
# Track generation: 1145..1435 -> 290-tiles track
# Epoch: 228
# BC	mean: 948.01	variance: 88.82
# 229
# Track generation: 1193..1496 -> 303-tiles track
# Epoch: 229
# BC	mean: 947.83	variance: 88.67
# 230
# Track generation: 1352..1694 -> 342-tiles track
# Epoch: 230
# BC	mean: 948.10	variance: 88.57
# 231
# Track generation: 1164..1459 -> 295-tiles track
# Epoch: 231
# BC	mean: 948.43	variance: 88.51
# 232
# Track generation: 1135..1423 -> 288-tiles track
# Epoch: 232
# BC	mean: 948.78	variance: 88.49
# 233
# Track generation: 1186..1487 -> 301-tiles track
# Epoch: 233
# BC	mean: 948.60	variance: 88.34
# 234
# Track generation: 1122..1415 -> 293-tiles track
# Epoch: 234
# BC	mean: 948.40	variance: 88.20
# 235
# Track generation: 1175..1479 -> 304-tiles track
# Epoch: 235
# BC	mean: 948.72	variance: 88.15
# 236
# Track generation: 1184..1484 -> 300-tiles track
# Epoch: 236
# BC	mean: 948.54	variance: 88.00
# 237
# Track generation: 1286..1612 -> 326-tiles track
# Epoch: 237
# BC	mean: 948.35	variance: 87.86
# 238
# Track generation: 1331..1668 -> 337-tiles track
# Epoch: 238
# BC	mean: 948.09	variance: 87.77
# 239
# Track generation: 1145..1440 -> 295-tiles track
# Epoch: 239
# BC	mean: 948.41	variance: 87.72
# 240
# Track generation: 1080..1354 -> 274-tiles track
# Epoch: 240
# BC	mean: 948.79	variance: 87.73
# 241
# Track generation: 1209..1515 -> 306-tiles track
# Epoch: 241
# BC	mean: 947.86	variance: 88.72
# 242
# Track generation: 1316..1650 -> 334-tiles track
# Epoch: 242
# BC	mean: 948.13	variance: 88.63
# 243
# Track generation: 1125..1418 -> 293-tiles track
# Epoch: 243
# BC	mean: 947.97	variance: 88.49
# 244
# Track generation: 1238..1552 -> 314-tiles track
# Epoch: 244
# BC	mean: 947.78	variance: 88.35
# 245
# Track generation: 890..1120 -> 230-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1084..1359 -> 275-tiles track
# Epoch: 245
# BC	mean: 948.15	variance: 88.36
# 246
# Track generation: 1499..1882 -> 383-tiles track
# Epoch: 246
# BC	mean: 948.01	variance: 88.20
# 247
# Track generation: 1215..1523 -> 308-tiles track
# Epoch: 247
# BC	mean: 947.83	variance: 88.07
# 248
# Track generation: 1039..1303 -> 264-tiles track
# Epoch: 248
# BC	mean: 947.61	variance: 87.96
# 249
# Track generation: 1135..1423 -> 288-tiles track
# Epoch: 249
# BC	mean: 947.47	variance: 87.81
# 250
# Track generation: 1035..1307 -> 272-tiles track
# Epoch: 250
# BC	mean: 947.81	variance: 87.80
# 251
# Track generation: 1161..1455 -> 294-tiles track
# Epoch: 251
# BC	mean: 948.12	variance: 87.76
# 252
# Track generation: 1049..1323 -> 274-tiles track
# Epoch: 252
# BC	mean: 948.45	variance: 87.74
# 253
# Track generation: 1034..1305 -> 271-tiles track
# Epoch: 253
# BC	mean: 948.31	variance: 87.59
# 254
# Track generation: 1233..1545 -> 312-tiles track
# Epoch: 254
# BC	mean: 948.12	variance: 87.47
# 255
# Track generation: 1141..1437 -> 296-tiles track
# Epoch: 255
# BC	mean: 947.88	variance: 87.38
# 256
# Track generation: 1301..1630 -> 329-tiles track
# Epoch: 256
# BC	mean: 948.13	variance: 87.31
# 257
# Track generation: 1320..1654 -> 334-tiles track
# Epoch: 257
# BC	mean: 948.41	variance: 87.25
# 258
# Track generation: 1195..1498 -> 303-tiles track
# Epoch: 258
# BC	mean: 948.21	variance: 87.15
# 259
# Track generation: 1185..1485 -> 300-tiles track
# Epoch: 259
# BC	mean: 948.52	variance: 87.12
# 260
# Track generation: 1184..1484 -> 300-tiles track
# Epoch: 260
# BC	mean: 948.31	variance: 87.01
# 261
# Track generation: 1149..1443 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1219..1528 -> 309-tiles track
# Epoch: 261
# BC	mean: 948.11	variance: 86.91
# 262
# Track generation: 1271..1592 -> 321-tiles track
# Epoch: 262
# BC	mean: 948.38	variance: 86.85
# 263
# Track generation: 1272..1594 -> 322-tiles track
# Epoch: 263
# BC	mean: 948.61	variance: 86.76
# 264
# Track generation: 1244..1559 -> 315-tiles track
# Epoch: 264
# BC	mean: 948.89	variance: 86.72
# 265
# Track generation: 1121..1405 -> 284-tiles track
# Epoch: 265
# BC	mean: 948.71	variance: 86.60
# 266
# Track generation: 963..1213 -> 250-tiles track
# Epoch: 266
# BC	mean: 949.05	variance: 86.62
# 267
# Track generation: 1103..1383 -> 280-tiles track
# Epoch: 267
# BC	mean: 948.93	variance: 86.48
# 268
# Track generation: 1297..1625 -> 328-tiles track
# Epoch: 268
# BC	mean: 946.54	variance: 94.70
# 269
# Track generation: 1208..1514 -> 306-tiles track
# Epoch: 269
# BC	mean: 946.83	variance: 94.64
# 270
# Track generation: 1209..1515 -> 306-tiles track
# Epoch: 270
# BC	mean: 946.67	variance: 94.50
# 271
# Track generation: 1386..1737 -> 351-tiles track
# Epoch: 271
# BC	mean: 946.78	variance: 94.34
# 272
# Track generation: 1017..1280 -> 263-tiles track
# Epoch: 272
# BC	mean: 947.12	variance: 94.33
# 273
# Track generation: 1347..1688 -> 341-tiles track
# Epoch: 273
# BC	mean: 946.86	variance: 94.26
# 274
# Track generation: 1154..1446 -> 292-tiles track
# Epoch: 274
# BC	mean: 946.74	variance: 94.11
# 275
# Track generation: 1072..1343 -> 271-tiles track
# Epoch: 275
# BC	mean: 946.50	variance: 94.02
# 276
# Track generation: 1156..1449 -> 293-tiles track
# Epoch: 276
# BC	mean: 946.79	variance: 93.96
# 277
# Track generation: 1351..1693 -> 342-tiles track
# Epoch: 277
# BC	mean: 946.60	variance: 93.85
# 278
# Track generation: 1272..1603 -> 331-tiles track
# Epoch: 278
# BC	mean: 946.44	variance: 93.72
# 279
# Track generation: 1168..1464 -> 296-tiles track
# Epoch: 279
# BC	mean: 946.72	variance: 93.67
# 280
# Track generation: 1058..1331 -> 273-tiles track
# Epoch: 280
# BC	mean: 947.04	variance: 93.66
# 281
# Track generation: 1064..1338 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1224..1534 -> 310-tiles track
# Epoch: 281
# BC	mean: 947.32	variance: 93.61
# 282
# Track generation: 1060..1329 -> 269-tiles track
# Epoch: 282
# BC	mean: 947.22	variance: 93.45
# 283
# Track generation: 1071..1343 -> 272-tiles track
# Epoch: 283
# BC	mean: 947.53	variance: 93.43
# 284
# Track generation: 1321..1661 -> 340-tiles track
# Epoch: 284
# BC	mean: 947.75	variance: 93.34
# 285
# Track generation: 1211..1518 -> 307-tiles track
# Epoch: 285
# BC	mean: 947.61	variance: 93.21
# 286
# Track generation: 1120..1404 -> 284-tiles track
# Epoch: 286
# BC	mean: 947.46	variance: 93.08
# 287
# Track generation: 1067..1338 -> 271-tiles track
# Epoch: 287
# BC	mean: 947.28	variance: 92.96
# 288
# Track generation: 1124..1409 -> 285-tiles track
# Epoch: 288
# BC	mean: 947.56	variance: 92.92
# 289
# Track generation: 1232..1547 -> 315-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1114..1405 -> 291-tiles track
# Epoch: 289
# BC	mean: 947.39	variance: 92.81
# 290
# Track generation: 1223..1534 -> 311-tiles track
# Epoch: 290
# BC	mean: 947.17	variance: 92.72
# 291
# Track generation: 1028..1292 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1244..1559 -> 315-tiles track
# Epoch: 291
# BC	mean: 945.34	variance: 97.70
# 292
# Track generation: 1138..1426 -> 288-tiles track
# Epoch: 292
# BC	mean: 945.61	variance: 97.64
# 293
# Track generation: 1152..1444 -> 292-tiles track
# Epoch: 293
# BC	mean: 945.89	variance: 97.60
# 294
# Track generation: 1217..1536 -> 319-tiles track
# Epoch: 294
# BC	mean: 946.12	variance: 97.51
# 295
# Track generation: 1122..1412 -> 290-tiles track
# Epoch: 295
# BC	mean: 945.97	variance: 97.38
# 296
# Track generation: 1092..1369 -> 277-tiles track
# Epoch: 296
# BC	mean: 946.27	variance: 97.34
# 297
# Track generation: 1067..1342 -> 275-tiles track
# Epoch: 297
# BC	mean: 946.55	variance: 97.31
# 298
# Track generation: 1026..1289 -> 263-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 944..1187 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1172..1469 -> 297-tiles track
# Epoch: 298
# BC	mean: 946.82	variance: 97.25
# 299
# Track generation: 1167..1462 -> 295-tiles track
# Epoch: 299
# BC	mean: 946.60	variance: 97.17
# 300
# Track generation: 1152..1444 -> 292-tiles track
# Epoch: 300
# BC	mean: 946.88	variance: 97.12
# 301
# Track generation: 1170..1467 -> 297-tiles track
# Epoch: 301
# BC	mean: 946.73	variance: 97.00
# 302
# Track generation: 1056..1324 -> 268-tiles track
# Epoch: 302
# BC	mean: 946.61	variance: 96.86
# 303
# Track generation: 1300..1637 -> 337-tiles track
# Epoch: 303
# BC	mean: 946.73	variance: 96.72
# 304
# Track generation: 1176..1474 -> 298-tiles track
# Epoch: 304
# BC	mean: 946.60	variance: 96.59
# 305
# Track generation: 975..1228 -> 253-tiles track
# Epoch: 305
# BC	mean: 946.90	variance: 96.58
# 306
# Track generation: 1095..1373 -> 278-tiles track
# Epoch: 306
# BC	mean: 946.75	variance: 96.46
# 307
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 307
# BC	mean: 946.67	variance: 96.31
# 308
# Track generation: 1113..1395 -> 282-tiles track
# Epoch: 308
# BC	mean: 946.51	variance: 96.19
# 309
# Track generation: 1220..1535 -> 315-tiles track
# Epoch: 309
# BC	mean: 946.74	variance: 96.12
# 310
# Track generation: 1282..1607 -> 325-tiles track
# Epoch: 310
# BC	mean: 946.97	variance: 96.05
# 311
# Track generation: 1087..1363 -> 276-tiles track
# Epoch: 311
# BC	mean: 946.87	variance: 95.92
# 312
# Track generation: 1359..1703 -> 344-tiles track
# Epoch: 312
# BC	mean: 947.08	variance: 95.84
# 313
# Track generation: 1171..1467 -> 296-tiles track
# Epoch: 313
# BC	mean: 947.34	variance: 95.79
# 314
# Track generation: 1100..1379 -> 279-tiles track
# Epoch: 314
# BC	mean: 947.13	variance: 95.71
# 315
# Track generation: 1389..1740 -> 351-tiles track
# Epoch: 315
# BC	mean: 947.32	variance: 95.62
# 316
# Track generation: 1188..1489 -> 301-tiles track
# Epoch: 316
# BC	mean: 947.56	variance: 95.56
# 317
# Track generation: 1197..1510 -> 313-tiles track
# Epoch: 317
# BC	mean: 947.77	variance: 95.48
# 318
# Track generation: 1148..1439 -> 291-tiles track
# Epoch: 318
# BC	mean: 948.03	variance: 95.44
# 319
# Track generation: 1205..1510 -> 305-tiles track
# Epoch: 319
# BC	mean: 947.31	variance: 96.15
# 320
# Track generation: 1011..1268 -> 257-tiles track
# Epoch: 320
# BC	mean: 947.17	variance: 96.03
# 321
# Track generation: 1004..1266 -> 262-tiles track
# Epoch: 321
# BC	mean: 947.44	variance: 96.01
# 322
# Track generation: 1208..1514 -> 306-tiles track
# Epoch: 322
# BC	mean: 947.67	variance: 95.94
# 323
# Track generation: 1219..1528 -> 309-tiles track
# Epoch: 323
# BC	mean: 947.45	variance: 95.87
# 324
# Track generation: 1086..1372 -> 286-tiles track
# Epoch: 324
# BC	mean: 947.69	variance: 95.83
# 325
# Track generation: 1143..1434 -> 291-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 325
# BC	mean: 947.59	variance: 95.70
# 326
# Track generation: 1186..1495 -> 309-tiles track
# Epoch: 326
# BC	mean: 947.47	variance: 95.57
# 327
# Track generation: 1164..1459 -> 295-tiles track
# Epoch: 327
# BC	mean: 947.33	variance: 95.46
# 328
# Track generation: 1032..1294 -> 262-tiles track
# Epoch: 328
# BC	mean: 947.22	variance: 95.34
# 329
# Track generation: 1085..1368 -> 283-tiles track
# Epoch: 329
# BC	mean: 947.47	variance: 95.31
# 330
# Track generation: 1175..1479 -> 304-tiles track
# Epoch: 330
# BC	mean: 947.70	variance: 95.25
# 331
# Track generation: 1081..1352 -> 271-tiles track
# Epoch: 331
# BC	mean: 947.53	variance: 95.16
# 332
# Track generation: 1064..1334 -> 270-tiles track
# Epoch: 332
# BC	mean: 947.43	variance: 95.03
# 333
# Track generation: 1059..1328 -> 269-tiles track
# Epoch: 333
# BC	mean: 947.69	variance: 95.01
# 334
# Track generation: 1131..1418 -> 287-tiles track
# Epoch: 334
# BC	mean: 947.53	variance: 94.91
# 335
# Track generation: 1120..1404 -> 284-tiles track
# Epoch: 335
# BC	mean: 947.78	variance: 94.88
# 336
# Track generation: 1046..1320 -> 274-tiles track
# Epoch: 336
# BC	mean: 947.66	variance: 94.77
# 337
# Track generation: 1092..1369 -> 277-tiles track
# Epoch: 337
# BC	mean: 947.51	variance: 94.66
# 338
# Track generation: 1051..1316 -> 265-tiles track
# Epoch: 338
# BC	mean: 947.34	variance: 94.58
# 339
# Track generation: 1232..1544 -> 312-tiles track
# Epoch: 339
# BC	mean: 947.56	variance: 94.53
# 340
# Track generation: 1161..1455 -> 294-tiles track
# Epoch: 340
# BC	mean: 947.80	variance: 94.49
# 341
# Track generation: 1075..1348 -> 273-tiles track
# Epoch: 341
# BC	mean: 947.71	variance: 94.37
# 342
# Track generation: 1010..1275 -> 265-tiles track
# Epoch: 342
# BC	mean: 947.97	variance: 94.35
# 343
# Track generation: 1183..1483 -> 300-tiles track
# Epoch: 343
# BC	mean: 948.21	variance: 94.31
# 344
# Track generation: 1220..1529 -> 309-tiles track
# Epoch: 344
# BC	mean: 948.06	variance: 94.22
# 345
# Track generation: 1170..1472 -> 302-tiles track
# Epoch: 345
# BC	mean: 948.27	variance: 94.16
# 346
# Track generation: 1245..1565 -> 320-tiles track
# Epoch: 346
# BC	mean: 948.47	variance: 94.10
# 347
# Track generation: 1149..1442 -> 293-tiles track
# Epoch: 347
# BC	mean: 948.27	variance: 94.05
# 348
# Track generation: 1096..1374 -> 278-tiles track
# Epoch: 348
# BC	mean: 948.16	variance: 93.93
# 349
# Track generation: 1009..1274 -> 265-tiles track
# Epoch: 349
# BC	mean: 948.40	variance: 93.90
# 350
# Track generation: 999..1253 -> 254-tiles track
# Epoch: 350
# BC	mean: 948.27	variance: 93.80
# 351
# Track generation: 1121..1414 -> 293-tiles track
# Epoch: 351
# BC	mean: 948.11	variance: 93.71
# 352
# Track generation: 1145..1436 -> 291-tiles track
# Epoch: 352
# BC	mean: 947.90	variance: 93.66
# 353
# Track generation: 1146..1442 -> 296-tiles track
# Epoch: 353
# BC	mean: 948.11	variance: 93.61
# 354
# Track generation: 1098..1376 -> 278-tiles track
# Epoch: 354
# BC	mean: 948.02	variance: 93.49
# 355
# Track generation: 1386..1736 -> 350-tiles track
# Epoch: 355
# BC	mean: 948.14	variance: 93.39
# 356
# Track generation: 1239..1553 -> 314-tiles track
# Epoch: 356
# BC	mean: 947.56	variance: 93.91
# 357
# Track generation: 979..1233 -> 254-tiles track
# Epoch: 357
# BC	mean: 947.81	variance: 93.90
# 358
# Track generation: 1084..1367 -> 283-tiles track
# Epoch: 358
# BC	mean: 947.65	variance: 93.82
# 359
# Track generation: 1108..1387 -> 279-tiles track
# Epoch: 359
# BC	mean: 947.50	variance: 93.73
# 360
# Track generation: 1466..1837 -> 371-tiles track
# Epoch: 360
# BC	mean: 947.54	variance: 93.61
# 361
# Track generation: 1232..1545 -> 313-tiles track
# Epoch: 361
# BC	mean: 947.40	variance: 93.52
# 362
# Track generation: 1304..1634 -> 330-tiles track
# Epoch: 362
# BC	mean: 947.26	variance: 93.42
# 363
# Track generation: 1064..1334 -> 270-tiles track
# Epoch: 363
# BC	mean: 947.18	variance: 93.31
# 364
# Track generation: 1075..1348 -> 273-tiles track
# Epoch: 364
# BC	mean: 947.42	variance: 93.29
# 365
# Track generation: 1062..1339 -> 277-tiles track
# Epoch: 365
# BC	mean: 947.65	variance: 93.26
# 366
# Track generation: 1087..1363 -> 276-tiles track
# Epoch: 366
# BC	mean: 947.54	variance: 93.16
# 367
# Track generation: 1079..1353 -> 274-tiles track
# Epoch: 367
# BC	mean: 947.78	variance: 93.15
# 368
# Track generation: 1189..1491 -> 302-tiles track
# Epoch: 368
# BC	mean: 947.98	variance: 93.10
# 369
# Track generation: 1106..1387 -> 281-tiles track
# Epoch: 369
# BC	mean: 948.20	variance: 93.08
# 370
# Track generation: 1201..1505 -> 304-tiles track
# Epoch: 370
# BC	mean: 948.03	variance: 93.01
# 371
# Track generation: 1144..1440 -> 296-tiles track
# Epoch: 371
# BC	mean: 947.91	variance: 92.91
# 372
# Track generation: 1301..1629 -> 328-tiles track
# Epoch: 372
# BC	mean: 948.09	variance: 92.85
# 373
# Track generation: 1076..1359 -> 283-tiles track
# Epoch: 373
# BC	mean: 948.30	variance: 92.82
# 374
# Track generation: 1198..1507 -> 309-tiles track
# Epoch: 374
# BC	mean: 948.16	variance: 92.73
# 375
# Track generation: 1132..1419 -> 287-tiles track
# Epoch: 375
# BC	mean: 948.39	variance: 92.71
# 376
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 376
# BC	mean: 948.24	variance: 92.63
# 377
# Track generation: 1127..1413 -> 286-tiles track
# Epoch: 377
# BC	mean: 948.09	variance: 92.55
# 378
# Track generation: 1083..1358 -> 275-tiles track
# Epoch: 378
# BC	mean: 948.00	variance: 92.45
# 379
# Track generation: 1127..1421 -> 294-tiles track
# Epoch: 379
# BC	mean: 947.83	variance: 92.39
# 380
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 380
# BC	mean: 948.05	variance: 92.37
# 381
# Track generation: 1136..1424 -> 288-tiles track
# Epoch: 381
# BC	mean: 947.93	variance: 92.27
# 382
# Track generation: 1132..1426 -> 294-tiles track
# Epoch: 382
# BC	mean: 948.14	variance: 92.24
# 383
# Track generation: 1115..1398 -> 283-tiles track
# Epoch: 383
# BC	mean: 948.00	variance: 92.16
# 384
# Track generation: 1184..1484 -> 300-tiles track
# Epoch: 384
# BC	mean: 948.19	variance: 92.12
# 385
# Track generation: 1145..1435 -> 290-tiles track
# Epoch: 385
# BC	mean: 948.41	variance: 92.09
# 386
# Track generation: 1151..1443 -> 292-tiles track
# Epoch: 386
# BC	mean: 948.61	variance: 92.06
# 387
# Track generation: 1315..1648 -> 333-tiles track
# Epoch: 387
# BC	mean: 948.45	variance: 91.99
# 388
# Track generation: 1052..1319 -> 267-tiles track
# Epoch: 388
# BC	mean: 948.38	variance: 91.89
# 389
# Track generation: 1231..1543 -> 312-tiles track
# Epoch: 389
# BC	mean: 948.11	variance: 91.92
# 390
# Track generation: 1151..1443 -> 292-tiles track
# Epoch: 390
# BC	mean: 948.32	variance: 91.89
# 391
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 391
# BC	mean: 948.53	variance: 91.87
# 392
# Track generation: 1390..1741 -> 351-tiles track
# Epoch: 392
# BC	mean: 948.68	variance: 91.80
# 393
# Track generation: 1308..1640 -> 332-tiles track
# Epoch: 393
# BC	mean: 948.85	variance: 91.74
# 394
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 394
# BC	mean: 949.06	variance: 91.73
# 395
# Track generation: 1232..1547 -> 315-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1038..1302 -> 264-tiles track
# Epoch: 395
# BC	mean: 948.92	variance: 91.65
# 396
# Track generation: 1081..1364 -> 283-tiles track
# Epoch: 396
# BC	mean: 949.13	variance: 91.63
# 397
# Track generation: 1344..1684 -> 340-tiles track
# Epoch: 397
# BC	mean: 948.98	variance: 91.56
# 398
# Track generation: 1048..1320 -> 272-tiles track
# Epoch: 398
# BC	mean: 949.19	variance: 91.53
# 399
# Track generation: 1057..1326 -> 269-tiles track
# Epoch: 399
# BC	mean: 949.08	variance: 91.44
# 400
# Track generation: 1245..1566 -> 321-tiles track
# Epoch: 400
# BC	mean: 949.24	variance: 91.39
# 401
# Track generation: 1174..1471 -> 297-tiles track
# Epoch: 401
# BC	mean: 949.43	variance: 91.35
# 402
# Track generation: 1357..1701 -> 344-tiles track
# Epoch: 402
# BC	mean: 949.28	variance: 91.29
# 403
# Track generation: 1176..1474 -> 298-tiles track
# Epoch: 403
# BC	mean: 949.14	variance: 91.22
# 404
# Track generation: 990..1250 -> 260-tiles track
# Epoch: 404
# BC	mean: 948.99	variance: 91.16
# 405
# Track generation: 1333..1670 -> 337-tiles track
# Epoch: 405
# BC	mean: 948.74	variance: 91.19
# 406
# Track generation: 1175..1483 -> 308-tiles track
# Epoch: 406
# BC	mean: 948.63	variance: 91.10
# 407
# Track generation: 1169..1466 -> 297-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1162..1456 -> 294-tiles track
# Epoch: 407
# BC	mean: 948.51	variance: 91.02
# 408
# Track generation: 960..1210 -> 250-tiles track
# Epoch: 408
# BC	mean: 948.74	variance: 91.03
# 409
# Track generation: 1188..1489 -> 301-tiles track
# Epoch: 409
# BC	mean: 948.62	variance: 90.96
# 410
# Track generation: 1043..1308 -> 265-tiles track
# Epoch: 410
# BC	mean: 948.54	variance: 90.86
# 411
# Track generation: 1140..1429 -> 289-tiles track
# Epoch: 411
# BC	mean: 948.40	variance: 90.79
# 412
# Track generation: 879..1105 -> 226-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1112..1398 -> 286-tiles track
# Epoch: 412
# BC	mean: 948.26	variance: 90.72
# 413
# Track generation: 1227..1538 -> 311-tiles track
# Epoch: 413
# BC	mean: 947.80	variance: 91.11
# 414
# Track generation: 1341..1690 -> 349-tiles track
# Epoch: 414
# BC	mean: 947.80	variance: 91.00
# 415
# Track generation: 1047..1313 -> 266-tiles track
# Epoch: 415
# BC	mean: 947.69	variance: 90.91
# 416
# Track generation: 1013..1278 -> 265-tiles track
# Epoch: 416
# BC	mean: 947.62	variance: 90.81
# 417
# Track generation: 1211..1518 -> 307-tiles track
# Epoch: 417
# BC	mean: 947.47	variance: 90.76
# 418
# Track generation: 1068..1339 -> 271-tiles track
# Epoch: 418
# BC	mean: 947.68	variance: 90.75
# 419
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 419
# BC	mean: 947.56	variance: 90.67
# 420
# Track generation: 1311..1643 -> 332-tiles track
# Epoch: 420
# BC	mean: 947.72	variance: 90.62
# 421
# Track generation: 1071..1343 -> 272-tiles track
# Epoch: 421
# BC	mean: 947.92	variance: 90.61
# 422
# Track generation: 997..1255 -> 258-tiles track
# Epoch: 422
# BC	mean: 948.14	variance: 90.61
# 423
# Track generation: 1010..1267 -> 257-tiles track
# Epoch: 423
# BC	mean: 948.35	variance: 90.61
# 424
# Track generation: 1284..1609 -> 325-tiles track
# Epoch: 424
# BC	mean: 948.20	variance: 90.56
# 425
# Track generation: 1071..1343 -> 272-tiles track
# Epoch: 425
# BC	mean: 948.10	variance: 90.47
# 426
# Track generation: 1181..1480 -> 299-tiles track
# Epoch: 426
# BC	mean: 948.29	variance: 90.45
# 427
# Track generation: 1029..1297 -> 268-tiles track
# Epoch: 427
# BC	mean: 948.19	variance: 90.37
# 428
# Track generation: 1212..1520 -> 308-tiles track
# Epoch: 428
# BC	mean: 948.06	variance: 90.30
# 429
# Track generation: 1126..1419 -> 293-tiles track
# Epoch: 429
# BC	mean: 948.25	variance: 90.27
# 430
# Track generation: 1130..1425 -> 295-tiles track
# Epoch: 430
# BC	mean: 948.14	variance: 90.19
# 431
# Track generation: 1153..1445 -> 292-tiles track
# Epoch: 431
# BC	mean: 947.98	variance: 90.15
# 432
# Track generation: 1161..1457 -> 296-tiles track
# Epoch: 432
# BC	mean: 947.91	variance: 90.06
# 433
# Track generation: 1064..1334 -> 270-tiles track
# Epoch: 433
# BC	mean: 947.82	variance: 89.97
# 434
# Track generation: 1263..1583 -> 320-tiles track
# Epoch: 434
# BC	mean: 947.72	variance: 89.89
# 435
# Track generation: 1044..1317 -> 273-tiles track
# Epoch: 435
# BC	mean: 947.91	variance: 89.88
# 436
# Track generation: 1166..1462 -> 296-tiles track
# Epoch: 436
# BC	mean: 947.80	variance: 89.80
# 437
# Track generation: 932..1174 -> 242-tiles track
# Epoch: 437
# BC	mean: 947.69	variance: 89.73
# 438
# Track generation: 1211..1518 -> 307-tiles track
# Epoch: 438
# BC	mean: 947.60	variance: 89.65
# 439
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 439
# BC	mean: 947.47	variance: 89.58
# 440
# Track generation: 1247..1563 -> 316-tiles track
# Epoch: 440
# BC	mean: 947.65	variance: 89.56
# 441
# Track generation: 994..1248 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1145..1435 -> 290-tiles track
# Epoch: 441
# BC	mean: 947.55	variance: 89.48
# 442
# Track generation: 1149..1440 -> 291-tiles track
# Epoch: 442
# BC	mean: 947.73	variance: 89.46
# 443
# Track generation: 1384..1734 -> 350-tiles track
# Epoch: 443
# BC	mean: 947.80	variance: 89.37
# 444
# Track generation: 1201..1514 -> 313-tiles track
# Epoch: 444
# BC	mean: 947.68	variance: 89.31
# 445
# Track generation: 1232..1544 -> 312-tiles track
# Epoch: 445
# BC	mean: 947.85	variance: 89.28
# 446
# Track generation: 1181..1486 -> 305-tiles track
# Epoch: 446
# BC	mean: 947.72	variance: 89.22
# 447
# Track generation: 1075..1348 -> 273-tiles track
# Epoch: 447
# BC	mean: 947.90	variance: 89.21
# 448
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 448
# BC	mean: 948.09	variance: 89.19
# 449
# Track generation: 1102..1384 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1148..1439 -> 291-tiles track
# Epoch: 449
# BC	mean: 948.26	variance: 89.17
# 450
# Track generation: 1356..1699 -> 343-tiles track
# Epoch: 450
# BC	mean: 948.30	variance: 89.08
# 451
# Track generation: 1032..1296 -> 264-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1117..1406 -> 289-tiles track
# Epoch: 451
# BC	mean: 948.47	variance: 89.06
# 452
# Track generation: 1075..1348 -> 273-tiles track
# Epoch: 452
# BC	mean: 948.67	variance: 89.06
# 453
# Track generation: 1105..1385 -> 280-tiles track
# Epoch: 453
# BC	mean: 948.85	variance: 89.04
# 454
# Track generation: 1075..1354 -> 279-tiles track
# Epoch: 454
# BC	mean: 949.02	variance: 89.02
# 455
# Track generation: 1027..1288 -> 261-tiles track
# Epoch: 455
# BC	mean: 948.92	variance: 88.95
# 456
# Track generation: 1151..1443 -> 292-tiles track
# Epoch: 456
# BC	mean: 949.09	variance: 88.92
# 457
# Track generation: 1052..1325 -> 273-tiles track
# Epoch: 457
# BC	mean: 949.27	variance: 88.91
# 458
# Track generation: 1283..1608 -> 325-tiles track
# Epoch: 458
# BC	mean: 949.09	variance: 88.89
# 459
# Track generation: 1155..1448 -> 293-tiles track
# Epoch: 459
# BC	mean: 949.00	variance: 88.81
# ...
# BC	mean: 884.64	variance: 163.00
# 1315
# Track generation: 1065..1344 -> 279-tiles track
# Epoch: 1315
# BC	mean: 884.57	variance: 162.96
# 1316
# Track generation: 1247..1563 -> 316-tiles track
# Epoch: 1316
# BC	mean: 884.05	variance: 163.99
# 1317
# Track generation: 1216..1524 -> 308-tiles track
# Epoch: 1317
# BC	mean: 884.06	variance: 163.93
# 1318
# Track generation: 943..1191 -> 248-tiles track
# Epoch: 1318
# BC	mean: 884.00	variance: 163.88
# 1319
# Track generation: 1320..1654 -> 334-tiles track
# Epoch: 1319
# BC	mean: 883.64	variance: 164.35
# 1320
# Track generation: 1312..1644 -> 332-tiles track
# Epoch: 1320
# BC	mean: 883.44	variance: 164.44
# 1321
# Track generation: 974..1223 -> 249-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1230..1546 -> 316-tiles track
# Epoch: 1321
# BC	mean: 883.51	variance: 164.40
# 1322
# Track generation: 1098..1378 -> 280-tiles track
# Epoch: 1322
# BC	mean: 883.05	variance: 165.21
# 1323
# Track generation: 1244..1559 -> 315-tiles track
# Epoch: 1323
# BC	mean: 883.06	variance: 165.14
# 1324
# Track generation: 1144..1434 -> 290-tiles track
# Epoch: 1324
# BC	mean: 882.74	variance: 165.48
# 1325
# Track generation: 1171..1468 -> 297-tiles track
# Epoch: 1325
# BC	mean: 882.81	variance: 165.43
# 1326
# Track generation: 1130..1417 -> 287-tiles track
# Epoch: 1326
# BC	mean: 882.93	variance: 165.42
# 1327
# Track generation: 926..1169 -> 243-tiles track
# Epoch: 1327
# BC	mean: 882.72	variance: 165.53
# 1328
# Track generation: 1215..1523 -> 308-tiles track
# Epoch: 1328
# BC	mean: 882.74	variance: 165.47
# 1329
# Track generation: 1084..1359 -> 275-tiles track
# Epoch: 1329
# BC	mean: 882.71	variance: 165.41
# 1330
# Track generation: 1145..1438 -> 293-tiles track
# Epoch: 1330
# BC	mean: 882.28	variance: 166.08
# 1331
# Track generation: 1155..1448 -> 293-tiles track
# Epoch: 1331
# BC	mean: 882.33	variance: 166.03
# 1332
# Track generation: 1188..1489 -> 301-tiles track
# Epoch: 1332
# BC	mean: 882.23	variance: 166.01
# 1333
# Track generation: 969..1221 -> 252-tiles track
# Epoch: 1333
# BC	mean: 882.24	variance: 165.95
# 1334
# Track generation: 1124..1409 -> 285-tiles track
# Epoch: 1334
# BC	mean: 882.26	variance: 165.89
# 1335
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 1335
# BC	mean: 882.26	variance: 165.83
# 1336
# Track generation: 1135..1423 -> 288-tiles track
# Epoch: 1336
# BC	mean: 882.25	variance: 165.77
# 1337
# Track generation: 1171..1468 -> 297-tiles track
# Epoch: 1337
# BC	mean: 882.25	variance: 165.70
# 1338
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 1338
# BC	mean: 882.27	variance: 165.64
# 1339
# Track generation: 1161..1460 -> 299-tiles track
# Epoch: 1339
# BC	mean: 881.84	variance: 166.31
# 1340
# Track generation: 1203..1511 -> 308-tiles track
# Epoch: 1340
# BC	mean: 881.84	variance: 166.25
# 1341
# Track generation: 1080..1362 -> 282-tiles track
# Epoch: 1341
# BC	mean: 881.84	variance: 166.19
# 1342
# Track generation: 1196..1499 -> 303-tiles track
# Epoch: 1342
# BC	mean: 881.89	variance: 166.14
# 1343
# Track generation: 1052..1319 -> 267-tiles track
# Epoch: 1343
# BC	mean: 881.90	variance: 166.08
# 1344
# Track generation: 960..1211 -> 251-tiles track
# Epoch: 1344
# BC	mean: 882.01	variance: 166.07
# 1345
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 1345
# BC	mean: 881.99	variance: 166.00
# 1346
# Track generation: 1356..1699 -> 343-tiles track
# Epoch: 1346
# BC	mean: 881.89	variance: 165.98
# 1347
# Track generation: 1267..1588 -> 321-tiles track
# Epoch: 1347
# BC	mean: 881.86	variance: 165.93
# 1348
# Track generation: 1192..1494 -> 302-tiles track
# Epoch: 1348
# BC	mean: 881.85	variance: 165.87
# 1349
# Track generation: 1284..1609 -> 325-tiles track
# Epoch: 1349
# BC	mean: 881.90	variance: 165.82
# 1350
# Track generation: 1056..1324 -> 268-tiles track
# Epoch: 1350
# BC	mean: 881.89	variance: 165.76
# 1351
# Track generation: 1115..1398 -> 283-tiles track
# Epoch: 1351
# BC	mean: 881.83	variance: 165.71
# 1352
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 1352
# BC	mean: 881.83	variance: 165.64
# 1353
# Track generation: 1207..1513 -> 306-tiles track
# Epoch: 1353
# BC	mean: 881.84	variance: 165.58
# 1354
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 1354
# BC	mean: 881.40	variance: 166.30
# 1355
# Track generation: 1248..1570 -> 322-tiles track
# Epoch: 1355
# BC	mean: 881.41	variance: 166.24
# 1356
# Track generation: 1160..1457 -> 297-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1288..1614 -> 326-tiles track
# Epoch: 1356
# BC	mean: 880.92	variance: 167.17
# 1357
# Track generation: 968..1218 -> 250-tiles track
# Epoch: 1357
# BC	mean: 880.88	variance: 167.11
# 1358
# Track generation: 1211..1527 -> 316-tiles track
# Epoch: 1358
# BC	mean: 880.44	variance: 167.84
# 1359
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 1359
# BC	mean: 880.29	variance: 167.87
# 1360
# Track generation: 1144..1434 -> 290-tiles track
# Epoch: 1360
# BC	mean: 880.30	variance: 167.81
# 1361
# Track generation: 1176..1475 -> 299-tiles track
# Epoch: 1361
# BC	mean: 880.32	variance: 167.75
# 1362
# Track generation: 1157..1450 -> 293-tiles track
# Epoch: 1362
# BC	mean: 880.21	variance: 167.73
# 1363
# Track generation: 977..1234 -> 257-tiles track
# Epoch: 1363
# BC	mean: 880.31	variance: 167.71
# 1364
# Track generation: 1088..1364 -> 276-tiles track
# Epoch: 1364
# BC	mean: 880.32	variance: 167.65
# 1365
# Track generation: 1008..1264 -> 256-tiles track
# Epoch: 1365
# BC	mean: 880.29	variance: 167.59
# 1366
# Track generation: 1200..1504 -> 304-tiles track
# Epoch: 1366
# BC	mean: 880.30	variance: 167.53
# 1367
# Track generation: 1034..1297 -> 263-tiles track
# Epoch: 1367
# BC	mean: 880.24	variance: 167.48
# 1368
# Track generation: 1314..1654 -> 340-tiles track
# Epoch: 1368
# BC	mean: 880.33	variance: 167.45
# 1369
# Track generation: 1160..1459 -> 299-tiles track
# Epoch: 1369
# BC	mean: 880.39	variance: 167.41
# 1370
# Track generation: 1102..1382 -> 280-tiles track
# Epoch: 1370
# BC	mean: 879.95	variance: 168.15
# 1371
# Track generation: 1191..1493 -> 302-tiles track
# Epoch: 1371
# BC	mean: 879.95	variance: 168.09
# 1372
# Track generation: 1120..1404 -> 284-tiles track
# Epoch: 1372
# BC	mean: 879.97	variance: 168.03
# 1373
# Track generation: 990..1246 -> 256-tiles track
# Epoch: 1373
# BC	mean: 879.57	variance: 168.65
# 1374
# Track generation: 1279..1612 -> 333-tiles track
# Epoch: 1374
# BC	mean: 879.48	variance: 168.61
# 1375
# Track generation: 987..1239 -> 252-tiles track
# Epoch: 1375
# BC	mean: 879.50	variance: 168.55
# 1376
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 1376
# BC	mean: 879.50	variance: 168.49
# 1377
# Track generation: 1176..1474 -> 298-tiles track
# Epoch: 1377
# BC	mean: 879.61	variance: 168.48
# 1378
# Track generation: 1315..1657 -> 342-tiles track
# Epoch: 1378
# BC	mean: 879.69	variance: 168.44
# 1379
# Track generation: 1204..1508 -> 304-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1036..1303 -> 267-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 1379
# BC	mean: 879.80	variance: 168.43
# 1380
# Track generation: 1190..1492 -> 302-tiles track
# Epoch: 1380
# BC	mean: 879.81	variance: 168.37
# 1381
# Track generation: 1143..1433 -> 290-tiles track
# Epoch: 1381
# BC	mean: 879.91	variance: 168.36
# 1382
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 1382
# BC	mean: 880.02	variance: 168.34
# 1383
# Track generation: 1239..1551 -> 312-tiles track
# Epoch: 1383
# BC	mean: 880.12	variance: 168.32
# 1384
# Track generation: 990..1241 -> 251-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 1384
# BC	mean: 880.08	variance: 168.26
# 1385
# Track generation: 1087..1363 -> 276-tiles track
# Epoch: 1385
# BC	mean: 880.08	variance: 168.20
# 1386
# Track generation: 1096..1375 -> 279-tiles track
# Epoch: 1386
# BC	mean: 880.19	variance: 168.19
# 1387
# Track generation: 1152..1444 -> 292-tiles track
# Epoch: 1387
# BC	mean: 880.05	variance: 168.21
# 1388
# Track generation: 1102..1386 -> 284-tiles track
# Epoch: 1388
# BC	mean: 880.01	variance: 168.15
# 1389
# Track generation: 1123..1408 -> 285-tiles track
# Epoch: 1389
# BC	mean: 879.57	variance: 168.86
# 1390
# Track generation: 1254..1571 -> 317-tiles track
# Epoch: 1390
# BC	mean: 879.67	variance: 168.85
# 1391
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 1391
# BC	mean: 879.78	variance: 168.83
# 1392
# Track generation: 1304..1634 -> 330-tiles track
# Epoch: 1392
# BC	mean: 879.83	variance: 168.78
# 1393
# Track generation: 1177..1476 -> 299-tiles track
# Epoch: 1393
# BC	mean: 879.53	variance: 169.08
# 1394
# Track generation: 1029..1290 -> 261-tiles track
# Epoch: 1394
# BC	mean: 879.48	variance: 169.03
# 1395
# Track generation: 944..1188 -> 244-tiles track
# Epoch: 1395
# BC	mean: 879.47	variance: 168.97
# 1396
# Track generation: 964..1215 -> 251-tiles track
# Epoch: 1396
# BC	mean: 879.58	variance: 168.96
# 1397
# Track generation: 1068..1344 -> 276-tiles track
# Epoch: 1397
# BC	mean: 879.69	variance: 168.95
# 1398
# Track generation: 1156..1449 -> 293-tiles track
# Epoch: 1398
# BC	mean: 879.64	variance: 168.90
# 1399
# Track generation: 1180..1485 -> 305-tiles track
# Epoch: 1399
# BC	mean: 879.68	variance: 168.84
# 1400
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 1400
# BC	mean: 879.16	variance: 169.90
# 1401
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 1401
# BC	mean: 879.15	variance: 169.84
# 1402
# Track generation: 1264..1584 -> 320-tiles track
# Epoch: 1402
# BC	mean: 879.24	variance: 169.82
# 1403
# Track generation: 1043..1308 -> 265-tiles track
# Epoch: 1403
# BC	mean: 879.04	variance: 169.93
# 1404
# Track generation: 1296..1624 -> 328-tiles track
# Epoch: 1404
# BC	mean: 879.13	variance: 169.90
# 1405
# Track generation: 1172..1475 -> 303-tiles track
# Epoch: 1405
# BC	mean: 879.14	variance: 169.84
# 1406
# Track generation: 1010..1275 -> 265-tiles track
# Epoch: 1406
# BC	mean: 879.14	variance: 169.78
# 1407
# Track generation: 1106..1395 -> 289-tiles track
# Epoch: 1407
# BC	mean: 879.15	variance: 169.72
# 1408
# Track generation: 1083..1358 -> 275-tiles track
# Epoch: 1408
# BC	mean: 879.17	variance: 169.67
# 1409
# Track generation: 1003..1258 -> 255-tiles track
# Epoch: 1409
# BC	mean: 879.15	variance: 169.61
# 1410
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 1410
# BC	mean: 879.06	variance: 169.58
# 1411
# Track generation: 1085..1363 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1104..1390 -> 286-tiles track
# Epoch: 1411
# BC	mean: 879.14	variance: 169.55
# 1412
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 1412
# BC	mean: 879.14	variance: 169.49
# 1413
# Track generation: 1215..1523 -> 308-tiles track
# Epoch: 1413
# BC	mean: 879.14	variance: 169.43
# 1414
# Track generation: 1051..1318 -> 267-tiles track
# Epoch: 1414
# BC	mean: 878.70	variance: 170.19
# 1415
# Track generation: 1260..1579 -> 319-tiles track
# Epoch: 1415
# BC	mean: 878.69	variance: 170.13
# 1416
# Track generation: 1343..1683 -> 340-tiles track
# Epoch: 1416
# BC	mean: 878.75	variance: 170.09
# 1417
# Track generation: 996..1256 -> 260-tiles track
# Epoch: 1417
# BC	mean: 878.76	variance: 170.03
# 1418
# Track generation: 1264..1584 -> 320-tiles track
# Epoch: 1418
# BC	mean: 878.85	variance: 170.01
# 1419
# Track generation: 1335..1673 -> 338-tiles track
# Epoch: 1419
# BC	mean: 878.53	variance: 170.37
# 1420
# Track generation: 1236..1549 -> 313-tiles track
# Epoch: 1420
# BC	mean: 878.41	variance: 170.38
# 1421
# Track generation: 1233..1545 -> 312-tiles track
# Epoch: 1421
# BC	mean: 878.42	variance: 170.32
# 1422
# Track generation: 1240..1554 -> 314-tiles track
# Epoch: 1422
# BC	mean: 878.42	variance: 170.26
# 1423
# Track generation: 1051..1326 -> 275-tiles track
# Epoch: 1423
# BC	mean: 878.43	variance: 170.20
# 1424
# Track generation: 1207..1513 -> 306-tiles track
# Epoch: 1424
# BC	mean: 878.50	variance: 170.17
# 1425
# Track generation: 1216..1524 -> 308-tiles track
# Epoch: 1425
# BC	mean: 878.52	variance: 170.11
# 1426
# Track generation: 1319..1653 -> 334-tiles track
# Epoch: 1426
# BC	mean: 878.59	variance: 170.07
# 1427
# Track generation: 1163..1458 -> 295-tiles track
# Epoch: 1427
# BC	mean: 878.69	variance: 170.05
# 1428
# Track generation: 1050..1320 -> 270-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 1428
# BC	mean: 878.71	variance: 169.99
# 1429
# Track generation: 1067..1338 -> 271-tiles track
# Epoch: 1429
# BC	mean: 878.60	variance: 169.98
# 1430
# Track generation: 1135..1423 -> 288-tiles track
# Epoch: 1430
# BC	mean: 878.71	variance: 169.97
# 1431
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 1431
# BC	mean: 878.69	variance: 169.91
# 1432
# Track generation: 1164..1459 -> 295-tiles track
# Epoch: 1432
# BC	mean: 878.66	variance: 169.85
# 1433
# Track generation: 1187..1495 -> 308-tiles track
# Epoch: 1433
# BC	mean: 878.25	variance: 170.50
# 1434
# Track generation: 1363..1715 -> 352-tiles track
# Epoch: 1434
# BC	mean: 877.86	variance: 171.08
# 1435
# Track generation: 1099..1375 -> 276-tiles track
# Epoch: 1435
# BC	mean: 877.54	variance: 171.47
# 1436
# Track generation: 1208..1514 -> 306-tiles track
# Epoch: 1436
# BC	mean: 877.54	variance: 171.41
# 1437
# Track generation: 1021..1286 -> 265-tiles track
# Epoch: 1437
# BC	mean: 877.52	variance: 171.35
# 1438
# Track generation: 1191..1493 -> 302-tiles track
# Epoch: 1438
# BC	mean: 877.52	variance: 171.29
# 1439
# Track generation: 1300..1629 -> 329-tiles track
# Epoch: 1439
# BC	mean: 877.57	variance: 171.24
# 1440
# Track generation: 1255..1573 -> 318-tiles track
# Epoch: 1440
# BC	mean: 877.55	variance: 171.18
# 1441
# Track generation: 1327..1667 -> 340-tiles track
# Epoch: 1441
# BC	mean: 877.58	variance: 171.13
# 1442
# Track generation: 1181..1480 -> 299-tiles track
# Epoch: 1442
# BC	mean: 877.57	variance: 171.07
# 1443
# Track generation: 1088..1366 -> 278-tiles track
# Epoch: 1443
# BC	mean: 877.55	variance: 171.01
# 1444
# Track generation: 1089..1373 -> 284-tiles track
# Epoch: 1444
# BC	mean: 877.58	variance: 170.96
# 1445
# Track generation: 947..1187 -> 240-tiles track
# Epoch: 1445
# BC	mean: 877.58	variance: 170.90
# 1446
# Track generation: 1027..1293 -> 266-tiles track
# Epoch: 1446
# BC	mean: 877.59	variance: 170.84
# 1447
# Track generation: 1130..1417 -> 287-tiles track
# Epoch: 1447
# BC	mean: 877.59	variance: 170.78
# 1448
# Track generation: 1169..1465 -> 296-tiles track
# Epoch: 1448
# BC	mean: 877.61	variance: 170.72
# 1449
# Track generation: 1209..1515 -> 306-tiles track
# Epoch: 1449
# BC	mean: 877.56	variance: 170.67
# 1450
# Track generation: 1173..1471 -> 298-tiles track
# Epoch: 1450
# BC	mean: 877.39	variance: 170.73
# 1451
# Track generation: 1132..1419 -> 287-tiles track
# Epoch: 1451
# BC	mean: 877.40	variance: 170.67
# 1452
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 1452
# BC	mean: 877.41	variance: 170.61
# 1453
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 1453
# BC	mean: 877.28	variance: 170.63
# 1454
# Track generation: 1227..1538 -> 311-tiles track
# Epoch: 1454
# BC	mean: 877.28	variance: 170.57
# 1455
# Track generation: 950..1195 -> 245-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1187..1488 -> 301-tiles track
# Epoch: 1455
# BC	mean: 877.10	variance: 170.64
# 1456
# Track generation: 1111..1393 -> 282-tiles track
# Epoch: 1456
# BC	mean: 876.96	variance: 170.67
# 1457
# Track generation: 1203..1516 -> 313-tiles track
# Epoch: 1457
# BC	mean: 877.03	variance: 170.64
# 1458
# Track generation: 1192..1494 -> 302-tiles track
# Epoch: 1458
# BC	mean: 877.05	variance: 170.58
# 1459
# Track generation: 1080..1354 -> 274-tiles track
# Epoch: 1459
# BC	mean: 877.07	variance: 170.52
# 1460
# Track generation: 1006..1264 -> 258-tiles track
# Epoch: 1460
# BC	mean: 877.01	variance: 170.48
# 1461
# Track generation: 1064..1334 -> 270-tiles track
# Epoch: 1461
# BC	mean: 877.01	variance: 170.42
# 1462
# Track generation: 1200..1504 -> 304-tiles track
# Epoch: 1462
# BC	mean: 877.07	variance: 170.37
# 1463
# Track generation: 1002..1265 -> 263-tiles track
# Epoch: 1463
# BC	mean: 877.08	variance: 170.31
# 1464
# Track generation: 1113..1405 -> 292-tiles track
# Epoch: 1464
# BC	mean: 877.07	variance: 170.25
# 1465
# Track generation: 1049..1323 -> 274-tiles track
# Epoch: 1465
# BC	mean: 877.09	variance: 170.20
# 1466
# Track generation: 1113..1395 -> 282-tiles track
# Epoch: 1466
# BC	mean: 877.19	variance: 170.18
# 1467
# Track generation: 1228..1539 -> 311-tiles track

# %%
import math
import random
beta=1
my_prob = ['expert']*math.floor((beta*100)) + ['dagger']*math.floor((1-beta)*100)
random.choice(my_prob)
# Out:
# 'expert'

# %%
env.close()
