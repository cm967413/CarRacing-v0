# %%
import numpy as np
import time
import gym
import torch
import torch.nn as nn
import random
import queue
import matplotlib.pyplot as plt
import math
from IPython.display import clear_output
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
class Env():
    def __init__(self):
        self.env = gym.make('CarRacing-v0')
        self.reward_threshold = self.env.spec.reward_threshold

    def reset(self):
        self.counter = 0
        self.av_r = self.reward_memory()
        self.die = False
        img_rgb = self.env.reset()
        img_gray = self.rgb2gray(img_rgb)
        self.stack = [img_gray] * 4
        return np.array(self.stack)

    def step(self, action):
        total_reward = 0
        for i in range(8):
            img_rgb, reward, die, _ = self.env.step(action)
            # don't penalize "die state"
            if die:
                reward += 100
            # green penalty
            if np.mean(img_rgb[:, :, 1]) > 185.0:
                reward -= 0.05
            total_reward += reward
            # if no reward recently, end the episode
            done = True if self.av_r(reward) <= -0.1 else False
            if done or die:
                break
        img_gray = self.rgb2gray(img_rgb)
        self.stack.pop(0)
        self.stack.append(img_gray)
        assert len(self.stack) == 4
        return np.array(self.stack), total_reward, done, die

    def render(self):
        self.env.render()

    def close(self):
        self.env.close()
        
    @staticmethod
    def rgb2gray(rgb, norm=True):
        gray = np.dot(rgb[..., :], [0.299, 0.587, 0.114])
        if norm:
            # normalize
            gray = gray / 128. - 1.
        return gray

    @staticmethod
    def reward_memory():
        count = 0
        length = 100
        history = np.zeros(length)

        def memory(reward):
            nonlocal count
            history[count] = reward
            count = (count + 1) % length
            return np.mean(history)

        return memory


class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.cnn_base = nn.Sequential(  # input shape (4, 96, 96)
            nn.Conv2d(4, 8, kernel_size=4, stride=2),
            nn.ReLU(),  # activation
            nn.Conv2d(8, 16, kernel_size=3, stride=2),  # (8, 47, 47)
            nn.ReLU(),  # activation
            nn.Conv2d(16, 32, kernel_size=3, stride=2),  # (16, 23, 23)
            nn.ReLU(),  # activation
            nn.Conv2d(32, 64, kernel_size=3, stride=2),  # (32, 11, 11)
            nn.ReLU(),  # activation
            nn.Conv2d(64, 128, kernel_size=3, stride=1),  # (64, 5, 5)
            nn.ReLU(),  # activation
            nn.Conv2d(128, 256, kernel_size=3, stride=1),  # (128, 3, 3)
            nn.ReLU(),  # activation
        )  # output shape (256, 1, 1)
        self.v = nn.Sequential(nn.Linear(256, 100), nn.ReLU(), nn.Linear(100, 1))
        self.fc = nn.Sequential(nn.Linear(256, 100), nn.ReLU())
        self.alpha_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.beta_head = nn.Sequential(nn.Linear(100, 3), nn.Softplus())
        self.apply(self._weights_init)

    @staticmethod
    def _weights_init(m):
        if isinstance(m, nn.Conv2d):
            nn.init.xavier_uniform_(m.weight, gain=nn.init.calculate_gain('relu'))
            nn.init.constant_(m.bias, 0.1)

    def forward(self, x):
        x = self.cnn_base(x)
        x = x.view(-1, 256)
        v = self.v(x)
        x = self.fc(x)
        alpha = self.alpha_head(x) + 1
        beta = self.beta_head(x) + 1

        return (alpha, beta), v


class Agent():
    def __init__(self):
        self.net = Net().float().to(device)

    def select_action(self, state):
        state = torch.from_numpy(state).float().to(device).unsqueeze(0)
        with torch.no_grad():
            alpha, beta = self.net(state)[0]
        action = alpha / (alpha + beta)

        action = action.squeeze().cpu().numpy()
        return action

    def load_param(self):
        self.net.load_state_dict(torch.load('param/expert.pkl'))
    
     
class Classifier(nn.Module):
    def __init__(self,ch=2):
        super(Classifier,self).__init__()
        self.layer1 = torch.nn.Sequential(
            torch.nn.Conv2d(in_channels=4,out_channels=ch*8,kernel_size=7),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*8,out_channels=ch*16,kernel_size=5,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*16,out_channels=ch*32,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*32,out_channels=ch*32,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*32,out_channels=ch*64,kernel_size=3,stride=2),
            torch.nn.ReLU(),
            torch.nn.Conv2d(in_channels=ch*64,out_channels=ch*64,kernel_size=3,stride=2),
            torch.nn.ReLU()
        )
        self.v = torch.nn.Sequential(
            torch.nn.Linear(64*ch*1*1,256),
            torch.nn.ReLU()
        )
        self.fc = torch.nn.Linear(256,3)
        self.ch = ch
        
    def forward(self,x):
        x = self.layer1(x)
        x = x.view(x.size(0),-1)
        x = self.v(x)
        x = self.fc(x)
        
        x[:,0] = torch.tanh(x[:,0])
        x[:,1] = torch.sigmoid(x[:,1])
        x[:,2] = torch.sigmoid(x[:,2])
        return x

class ImgDataset(Dataset):
    def __init__(self, X, Y):
        self.X = X
        self.Y = Y
    def __len__(self):
        return len(self.X)
    def __getitem__(self, index):
        x = self.X[index]
        y = self.Y[index]
        return x, y

# %%
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

agent = Agent()
agent.load_param()

env = Env()

test_mean = []
test_std = []

epoch = 30
beta = 0.1
my_prob = list()
for i_ep in range(1, epoch+1):
    print('epoch {}'.format(i_ep))
    
    # choose which model in policy aggregation
    m = i_ep - 1
    model_prob = []
    for i in range(m):
        model_prob += [m-i]*math.floor(((beta*(1-beta)**i)*1000))
    if m >= 0:
        model_prob += [0]*math.floor((((1-beta)**m)*1000))
    
    # get trajectory
    X, Y = [], []
    T = 100
    for _ in range(T):
        score = 0
        state = env.reset()
        tmp_X, tmp_Y = [], []
        for t in range(1000):
            expert_action = agent.select_action(state)
            
            model_idx = random.choice(model_prob)
            if model_idx == 0:
                action = expert_action
            else:
                model = torch.load('pagger_model/pagger_model{}.pt'.format(model_idx))
                action = model(torch.tensor(state.reshape(1,4,96,96)).cuda().float())[0].cpu().detach().numpy()
            
            state_, reward, done, die = env.step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))

            tmp_X.append(state)
            tmp_Y.append(expert_action)
            
            # env.render()
            score += reward
            state = state_
            if done or die:
                break
        print("score: {}".format(score))
        
        if score > 800:
            for x in tmp_X:
                X.append(x)
            for y in tmp_Y:
                Y.append(y)
        
    env.close()
    print("Dataset size: {}".format(len(X)))
    
    # train new policy
    model = Classifier().cuda()  
    
    seed = np.random.randint(0, 10000)
    np.random.seed(seed)
    np.random.shuffle(X)
    np.random.seed(seed)
    np.random.shuffle(Y)
    
    train_x, val_x= X[:math.floor(len(X)*0.8)], X[math.floor(len(X)*0.8):]
    train_y, val_y= Y[:math.floor(len(Y)*0.8)], Y[math.floor(len(Y)*0.8):]
    batch_size = 128
    train_set = ImgDataset(train_x, train_y)
    val_set = ImgDataset(val_x, val_y)
    train_loader = DataLoader(train_set, batch_size=batch_size, shuffle=True, num_workers=0)
    val_loader = DataLoader(val_set, batch_size=batch_size, shuffle=False, num_workers=0)
            
    loss = nn.MSELoss().cuda()
    optimizer = torch.optim.Adam(model.parameters(), lr=5e-4, weight_decay=1e-4)
    num_train_epoch = 50
      
    for train_epoch in range(num_train_epoch):
        epoch_start_time = time.time()
        train_loss = 0.0
        val_loss = 0.0

        model.train() # 確保 model 是在 train model (開啟 Dropout 等...)
        for i, data in enumerate(train_loader):
            optimizer.zero_grad() # 用 optimizer 將 model 參數的 gradient 歸零
            train_pred = model(data[0].cuda().float())
            batch_loss = loss(train_pred, data[1].cuda()).cuda() # 計算 loss （注意 prediction 跟 label 必須同時在 CPU 或是 GPU 上）
            batch_loss.backward() # 利用 back propagation 算出每個參數的 gradient
            optimizer.step() # 以 optimizer 用 gradient 更新參數值

            train_loss += batch_loss.item()

        model.eval()
        with torch.no_grad():
            for i, data in enumerate(val_loader):
                val_pred = model(data[0].cuda().float())
                batch_loss = loss(val_pred, data[1].cuda())
                val_loss += batch_loss.item()

            #將結果 print 出來
            print('[%03d/%03d] %2.2f sec(s) Train Loss: %3.6f | Val loss: %3.6f' % \
                (train_epoch + 1, num_train_epoch, time.time()-epoch_start_time, train_loss/train_set.__len__(), val_loss/val_set.__len__()))
    torch.save(model, 'pagger_model/pagger_model{}.pt'.format(i_ep))
    
    # test policy
    num_test_epoch = 50
    total_score = 0
    scores = []
    
    m = i_ep
    model_prob = []
    for i in range(m):
        model_prob += [m-i]*math.floor(((beta*(1-beta)**i)*1000))
    # if m >= 0:
        # model_prob += [0]*math.floor((((1-beta)**m)*1000))
    
    for test_epoch in range(1, num_test_epoch+1):
        score = 0
        state = env.reset()
        
        for t in range(1000):
            model_idx = random.choice(model_prob)
            model = torch.load('pagger_model/pagger_model{}.pt'.format(model_idx))
            action = model(torch.tensor(state.reshape(1,4,96,96)).cuda().float())[0].cpu().detach().numpy()

            state_, reward, done, die = env.step(action * np.array([2., 1., 1.]) + np.array([-1., 0., 0.]))
            # env.render()
            score += reward
            state = state_
            if done or die:
                break
    
        total_score += score
        scores.append(score)
        
        mean = np.array(scores).mean()
        std = np.array(scores).std()
        print("Epoch: {}".format(test_epoch))
        print('Policy Aggregation\tmean: {:.2f}\tvariance: {:.2f}'.format(mean, std))
    
    test_mean.append(mean)
    test_std.append(std)
    
    np.save('./pagger_model/mean.npy', test_mean)
    np.save('./pagger_model/std.npy', test_std)
    
    plt.figure()
    plt.plot(test_mean)
    plt.figure()
    plt.plot(test_std)
    plt.show()
        
    env.close()
# Out:
# epoch 1
# Track generation: 1260..1579 -> 319-tiles track
# score: 891.9767295597276
# Track generation: 1009..1271 -> 262-tiles track
# score: 1035.899999999997
# Track generation: 1161..1455 -> 294-tiles track
# score: 903.3481228668761
# Track generation: 1062..1340 -> 278-tiles track
# score: 914.3898916967443
# Track generation: 1180..1479 -> 299-tiles track
# score: 909.7885906040096
# Track generation: 1160..1459 -> 299-tiles track
# score: 905.2885906040093
# Track generation: 1159..1456 -> 297-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1060..1329 -> 269-tiles track
# score: 913.8059701492394
# Track generation: 1044..1309 -> 265-tiles track
# score: 1036.4999999999877
# Track generation: 1171..1468 -> 297-tiles track
# score: 880.7945945945752
# Track generation: 1199..1503 -> 304-tiles track
# score: 1026.299999999993
# Track generation: 1292..1619 -> 327-tiles track
# score: 884.895092024527
# Track generation: 998..1255 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1287..1613 -> 326-tiles track
# score: 1012.0999999999897
# Track generation: 941..1189 -> 248-tiles track
# score: 920.7028340080827
# Track generation: 1048..1324 -> 276-tiles track
# score: 1029.6999999999878
# Track generation: 1131..1423 -> 292-tiles track
# score: 899.9271477663038
# Track generation: 1233..1545 -> 312-tiles track
# score: 1019.699999999986
# Track generation: 1109..1394 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1004..1259 -> 255-tiles track
# score: 1043.9999999999952
# Track generation: 1298..1627 -> 329-tiles track
# score: 1017.7999999999828
# Track generation: 1068..1339 -> 271-tiles track
# score: 901.0740740740608
# Track generation: 1160..1454 -> 294-tiles track
# score: 1033.399999999985
# Track generation: 1133..1420 -> 287-tiles track
# score: 1033.4999999999877
# Track generation: 1156..1449 -> 293-tiles track
# score: 1024.599999999984
# Track generation: 1091..1372 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1159..1453 -> 294-tiles track
# score: 912.2740614334291
# Track generation: 1105..1385 -> 280-tiles track
# score: 1035.7999999999906
# Track generation: 1158..1452 -> 294-tiles track
# score: 894.9221843003226
# Track generation: 1319..1653 -> 334-tiles track
# score: 990.9909909909704
# Track generation: 1196..1499 -> 303-tiles track
# score: 893.3324503311158
# Track generation: 1100..1388 -> 288-tiles track
# score: 910.1156794424954
# Track generation: 1192..1503 -> 311-tiles track
# score: 1021.3999999999936
# Track generation: 1065..1337 -> 272-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1277..1600 -> 323-tiles track
# score: 878.4496894409758
# Track generation: 1188..1489 -> 301-tiles track
# score: 894.1999999999898
# Track generation: 1031..1297 -> 266-tiles track
# score: 913.3792452830103
# Track generation: 1170..1467 -> 297-tiles track
# score: 911.2432432432247
# Track generation: 1191..1493 -> 302-tiles track
# score: 900.4332225913518
# Track generation: 1056..1324 -> 268-tiles track
# score: 1035.9999999999927
# Track generation: 1143..1433 -> 290-tiles track
# score: 1029.199999999994
# Track generation: 1258..1576 -> 318-tiles track
# score: 900.436277602512
# Track generation: 1305..1646 -> 341-tiles track
# score: 707.758823529404
# Track generation: 1046..1315 -> 269-tiles track
# score: 1030.2999999999874
# Track generation: 1104..1391 -> 287-tiles track
# score: 1025.9999999999873
# Track generation: 1216..1524 -> 308-tiles track
# score: 892.1560260586118
# Track generation: 1056..1324 -> 268-tiles track
# score: 920.3546816479303
# Track generation: 1124..1409 -> 285-tiles track
# score: 870.7253521126585
# Track generation: 1070..1341 -> 271-tiles track
# score: 1031.6999999999878
# Track generation: 1092..1371 -> 279-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1220..1529 -> 309-tiles track
# score: 1020.4999999999833
# Track generation: 1225..1538 -> 313-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1359..1702 -> 343-tiles track
# score: 744.6333333333189
# Track generation: 1196..1499 -> 303-tiles track
# score: 1023.1999999999922
# Track generation: 1171..1468 -> 297-tiles track
# score: 1031.1999999999841
# Track generation: 1034..1303 -> 269-tiles track
# score: 912.8059701492408
# Track generation: 1161..1455 -> 294-tiles track
# score: 896.6221843003229
# Track generation: 1223..1533 -> 310-tiles track
# score: 762.5877022653594
# Track generation: 1060..1329 -> 269-tiles track
# score: 1036.4999999999882
# Track generation: 1118..1406 -> 288-tiles track
# score: 917.8156794424963
# Track generation: 1046..1315 -> 269-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1088..1364 -> 276-tiles track
# score: 917.2636363636213
# Track generation: 1312..1644 -> 332-tiles track
# score: 892.4154078549631
# Track generation: 1304..1634 -> 330-tiles track
# score: 891.3629179331183
# Track generation: 1082..1357 -> 275-tiles track
# score: 1030.7999999999854
# Track generation: 1056..1330 -> 274-tiles track
# score: 1031.2999999999934
# Track generation: 1091..1368 -> 277-tiles track
# score: 894.6144927536149
# Track generation: 1130..1417 -> 287-tiles track
# score: 1026.6999999999866
# Track generation: 1164..1459 -> 295-tiles track
# score: 894.8904761904674
# Track generation: 991..1243 -> 252-tiles track
# score: 902.1115537848535
# Track generation: 1070..1349 -> 279-tiles track
# score: 903.811510791352
# Track generation: 1144..1434 -> 290-tiles track
# score: 1033.1999999999948
# Track generation: 1271..1593 -> 322-tiles track
# score: 894.4389408099468
# Track generation: 1171..1468 -> 297-tiles track
# score: 1027.5999999999835
# Track generation: 1160..1454 -> 294-tiles track
# score: 1029.9999999999843
# Track generation: 1139..1428 -> 289-tiles track
# score: 1031.8999999999842
# Track generation: 1108..1389 -> 281-tiles track
# score: 894.471428571412
# Track generation: 1256..1574 -> 318-tiles track
# score: 894.0817034700183
# Track generation: 1295..1623 -> 328-tiles track
# score: 1012.2999999999809
# Track generation: 1108..1389 -> 281-tiles track
# score: 914.1571428571274
# Track generation: 1208..1514 -> 306-tiles track
# score: 1021.6999999999883
# Track generation: 1102..1386 -> 284-tiles track
# score: 1025.8999999999874
# Track generation: 925..1160 -> 235-tiles track
# score: 1045.399999999992
# Track generation: 1184..1483 -> 299-tiles track
# score: 902.5214765100507
# Track generation: 1148..1439 -> 291-tiles track
# score: 888.6137931034323
# Track generation: 1092..1369 -> 277-tiles track
# score: 1031.6999999999935
# Track generation: 1136..1433 -> 297-tiles track
# score: 899.5648648648463
# Track generation: 1300..1630 -> 330-tiles track
# score: 1012.7999999999881
# Track generation: 1289..1615 -> 326-tiles track
# score: 879.2076923076806
# Track generation: 967..1213 -> 246-tiles track
# score: 918.1367346938626
# Track generation: 1148..1439 -> 291-tiles track
# score: 904.2068965517082
# Track generation: 1126..1412 -> 286-tiles track
# score: 1029.6999999999862
# Track generation: 1108..1389 -> 281-tiles track
# score: 910.8142857142711
# Track generation: 1046..1311 -> 265-tiles track
# score: 905.1727272727134
# Track generation: 1233..1545 -> 312-tiles track
# score: 889.0765273311745
# Track generation: 1268..1589 -> 321-tiles track
# score: 902.6749999999845
# Track generation: 1092..1379 -> 287-tiles track
# score: 1027.3999999999878
# Track generation: 1015..1275 -> 260-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1072..1344 -> 272-tiles track
# score: 1035.499999999994
# Track generation: 1108..1389 -> 281-tiles track
# score: 1029.8999999999864
# Track generation: 1035..1305 -> 270-tiles track
# score: 1029.6999999999903
# Track generation: 1190..1495 -> 305-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1100..1379 -> 279-tiles track
# score: 895.0172661870334
# Track generation: 1096..1374 -> 278-tiles track
# score: 1033.499999999996
# Track generation: 1230..1541 -> 311-tiles track
# score: 1021.1999999999923
# Track generation: 1031..1293 -> 262-tiles track
# score: 901.1114942528661
# Track generation: 1022..1286 -> 264-tiles track
# score: 1034.7999999999852
# Track generation: 956..1205 -> 249-tiles track
# score: 1039.1999999999903
# Track generation: 1180..1479 -> 299-tiles track
# score: 1027.1999999999853
# Track generation: 1004..1259 -> 255-tiles track
# score: 926.5629921259764
# Dataset size: 9472
# [001/050] 2.99 sec(s) Train Loss: 0.000379 | Val loss: 0.000177
# [002/050] 2.71 sec(s) Train Loss: 0.000119 | Val loss: 0.000086
# [003/050] 2.66 sec(s) Train Loss: 0.000075 | Val loss: 0.000069
# [004/050] 2.69 sec(s) Train Loss: 0.000059 | Val loss: 0.000057
# [005/050] 2.67 sec(s) Train Loss: 0.000049 | Val loss: 0.000047
# [006/050] 2.70 sec(s) Train Loss: 0.000045 | Val loss: 0.000043
# [007/050] 2.67 sec(s) Train Loss: 0.000041 | Val loss: 0.000041
# [008/050] 2.71 sec(s) Train Loss: 0.000040 | Val loss: 0.000042
# [009/050] 2.67 sec(s) Train Loss: 0.000039 | Val loss: 0.000039
# [010/050] 2.71 sec(s) Train Loss: 0.000037 | Val loss: 0.000036
# [011/050] 2.67 sec(s) Train Loss: 0.000036 | Val loss: 0.000038
# [012/050] 2.71 sec(s) Train Loss: 0.000035 | Val loss: 0.000035
# [013/050] 2.69 sec(s) Train Loss: 0.000035 | Val loss: 0.000039
# [014/050] 2.75 sec(s) Train Loss: 0.000035 | Val loss: 0.000034
# [015/050] 2.68 sec(s) Train Loss: 0.000032 | Val loss: 0.000037
# [016/050] 2.70 sec(s) Train Loss: 0.000032 | Val loss: 0.000035
# [017/050] 2.69 sec(s) Train Loss: 0.000030 | Val loss: 0.000030
# [018/050] 2.71 sec(s) Train Loss: 0.000031 | Val loss: 0.000030
# [019/050] 2.68 sec(s) Train Loss: 0.000029 | Val loss: 0.000030
# [020/050] 2.73 sec(s) Train Loss: 0.000029 | Val loss: 0.000035
# [021/050] 2.67 sec(s) Train Loss: 0.000029 | Val loss: 0.000032
# [022/050] 2.71 sec(s) Train Loss: 0.000028 | Val loss: 0.000031
# [023/050] 2.67 sec(s) Train Loss: 0.000027 | Val loss: 0.000028
# [024/050] 2.77 sec(s) Train Loss: 0.000028 | Val loss: 0.000034
# [025/050] 2.69 sec(s) Train Loss: 0.000027 | Val loss: 0.000029
# [026/050] 2.71 sec(s) Train Loss: 0.000026 | Val loss: 0.000033
# [027/050] 2.74 sec(s) Train Loss: 0.000026 | Val loss: 0.000031
# [028/050] 3.01 sec(s) Train Loss: 0.000026 | Val loss: 0.000031
# [029/050] 2.73 sec(s) Train Loss: 0.000027 | Val loss: 0.000030
# [030/050] 2.73 sec(s) Train Loss: 0.000026 | Val loss: 0.000027
# [031/050] 2.68 sec(s) Train Loss: 0.000024 | Val loss: 0.000033
# [032/050] 3.07 sec(s) Train Loss: 0.000026 | Val loss: 0.000032
# [033/050] 2.79 sec(s) Train Loss: 0.000024 | Val loss: 0.000027
# [034/050] 2.80 sec(s) Train Loss: 0.000025 | Val loss: 0.000029
# [035/050] 2.83 sec(s) Train Loss: 0.000024 | Val loss: 0.000029
# [036/050] 3.01 sec(s) Train Loss: 0.000023 | Val loss: 0.000025
# [037/050] 2.73 sec(s) Train Loss: 0.000023 | Val loss: 0.000027
# [038/050] 2.74 sec(s) Train Loss: 0.000023 | Val loss: 0.000024
# [039/050] 2.67 sec(s) Train Loss: 0.000024 | Val loss: 0.000028
# [040/050] 3.16 sec(s) Train Loss: 0.000022 | Val loss: 0.000025
# [041/050] 3.29 sec(s) Train Loss: 0.000024 | Val loss: 0.000028
# [042/050] 2.80 sec(s) Train Loss: 0.000023 | Val loss: 0.000026
# [043/050] 2.80 sec(s) Train Loss: 0.000022 | Val loss: 0.000026
# [044/050] 3.02 sec(s) Train Loss: 0.000021 | Val loss: 0.000025
# [045/050] 2.83 sec(s) Train Loss: 0.000021 | Val loss: 0.000025
# [046/050] 2.97 sec(s) Train Loss: 0.000021 | Val loss: 0.000024
# [047/050] 3.07 sec(s) Train Loss: 0.000022 | Val loss: 0.000026
# [048/050] 2.86 sec(s) Train Loss: 0.000021 | Val loss: 0.000029
# [049/050] 2.99 sec(s) Train Loss: 0.000021 | Val loss: 0.000030
# [050/050] 2.73 sec(s) Train Loss: 0.000021 | Val loss: 0.000032
# Track generation: 1244..1559 -> 315-tiles track
# Epoch: 1
# Policy Aggregation	mean: 242.82	variance: 0.00
# Track generation: 990..1248 -> 258-tiles track
# Epoch: 2
# Policy Aggregation	mean: 537.82	variance: 295.00
# Track generation: 1350..1692 -> 342-tiles track
# Epoch: 3
# Policy Aggregation	mean: 447.26	variance: 272.80
# Track generation: 1219..1528 -> 309-tiles track
# Epoch: 4
# Policy Aggregation	mean: 412.56	variance: 243.78
# Track generation: 1144..1434 -> 290-tiles track
# Epoch: 5
# Policy Aggregation	mean: 416.88	variance: 218.21
# Track generation: 1118..1410 -> 292-tiles track
# Epoch: 6
# Policy Aggregation	mean: 460.50	variance: 221.80
# Track generation: 1244..1559 -> 315-tiles track
# Epoch: 7
# Policy Aggregation	mean: 454.65	variance: 205.84
# Track generation: 908..1142 -> 234-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 976..1224 -> 248-tiles track
# Epoch: 8
# Policy Aggregation	mean: 502.17	variance: 229.96
# Track generation: 1201..1505 -> 304-tiles track
# Epoch: 9
# Policy Aggregation	mean: 484.56	variance: 222.45
# Track generation: 1092..1376 -> 284-tiles track
# Epoch: 10
# Policy Aggregation	mean: 525.25	variance: 243.79
# Track generation: 1255..1573 -> 318-tiles track
# Epoch: 11
# Policy Aggregation	mean: 543.30	variance: 239.35
# Track generation: 1197..1500 -> 303-tiles track
# Epoch: 12
# Policy Aggregation	mean: 519.92	variance: 241.92
# Track generation: 1267..1588 -> 321-tiles track
# Epoch: 13
# Policy Aggregation	mean: 511.85	variance: 234.11
# Track generation: 1077..1351 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1055..1323 -> 268-tiles track
# Epoch: 14
# Policy Aggregation	mean: 502.38	variance: 228.16
# Track generation: 1078..1351 -> 273-tiles track
# Epoch: 15
# Policy Aggregation	mean: 485.97	variance: 228.82
# Track generation: 1312..1644 -> 332-tiles track
# Epoch: 16
# Policy Aggregation	mean: 479.26	variance: 223.07
# Track generation: 1070..1351 -> 281-tiles track
# Epoch: 17
# Policy Aggregation	mean: 495.67	variance: 226.14
# Track generation: 1128..1414 -> 286-tiles track
# Epoch: 18
# Policy Aggregation	mean: 484.69	variance: 224.38
# Track generation: 1039..1303 -> 264-tiles track
# Epoch: 19
# Policy Aggregation	mean: 479.82	variance: 219.37
# Track generation: 1231..1543 -> 312-tiles track
# Epoch: 20
# Policy Aggregation	mean: 466.52	variance: 221.53
# Track generation: 1226..1540 -> 314-tiles track
# Epoch: 21
# Policy Aggregation	mean: 484.35	variance: 230.42
# Track generation: 1044..1309 -> 265-tiles track
# Epoch: 22
# Policy Aggregation	mean: 477.40	variance: 227.36
# Track generation: 1080..1354 -> 274-tiles track
# Epoch: 23
# Policy Aggregation	mean: 491.30	variance: 231.73
# Track generation: 1117..1407 -> 290-tiles track
# Epoch: 24
# Policy Aggregation	mean: 488.86	variance: 227.15
# Track generation: 1270..1592 -> 322-tiles track
# Epoch: 25
# Policy Aggregation	mean: 481.67	variance: 225.33
# Track generation: 1045..1316 -> 271-tiles track
# Epoch: 26
# Policy Aggregation	mean: 496.58	variance: 233.20
# Track generation: 1117..1400 -> 283-tiles track
# Epoch: 27
# Policy Aggregation	mean: 488.85	variance: 232.21
# Track generation: 1103..1384 -> 281-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1321..1655 -> 334-tiles track
# Epoch: 28
# Policy Aggregation	mean: 504.54	variance: 242.14
# Track generation: 1059..1328 -> 269-tiles track
# Epoch: 29
# Policy Aggregation	mean: 517.24	variance: 247.24
# Track generation: 1160..1454 -> 294-tiles track
# Epoch: 30
# Policy Aggregation	mean: 528.30	variance: 250.28
# Track generation: 1023..1291 -> 268-tiles track
# Epoch: 31
# Policy Aggregation	mean: 527.57	variance: 246.24
# Track generation: 1443..1808 -> 365-tiles track
# Epoch: 32
# Policy Aggregation	mean: 525.07	variance: 242.76
# Track generation: 1241..1563 -> 322-tiles track
# Epoch: 33
# Policy Aggregation	mean: 539.08	variance: 251.86
# Track generation: 1159..1453 -> 294-tiles track
# Epoch: 34
# Policy Aggregation	mean: 546.07	variance: 251.36
# Track generation: 1115..1402 -> 287-tiles track
# Epoch: 35
# Policy Aggregation	mean: 555.25	variance: 253.45
# Track generation: 1206..1519 -> 313-tiles track
# Epoch: 36
# Policy Aggregation	mean: 564.48	variance: 255.80
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 37
# Policy Aggregation	mean: 573.45	variance: 258.00
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 38
# Policy Aggregation	mean: 569.38	variance: 255.78
# Track generation: 1159..1453 -> 294-tiles track
# Epoch: 39
# Policy Aggregation	mean: 576.20	variance: 255.95
# Track generation: 1134..1422 -> 288-tiles track
# Epoch: 40
# Policy Aggregation	mean: 570.32	variance: 255.39
# Track generation: 1109..1390 -> 281-tiles track
# Epoch: 41
# Policy Aggregation	mean: 566.53	variance: 253.39
# Track generation: 1345..1693 -> 348-tiles track
# Epoch: 42
# Policy Aggregation	mean: 573.70	variance: 254.53
# Track generation: 1284..1609 -> 325-tiles track
# Epoch: 43
# Policy Aggregation	mean: 578.87	variance: 253.77
# Track generation: 1127..1412 -> 285-tiles track
# Epoch: 44
# Policy Aggregation	mean: 571.99	variance: 254.89
# Track generation: 1324..1659 -> 335-tiles track
# Epoch: 45
# Policy Aggregation	mean: 574.80	variance: 252.73
# Track generation: 1184..1484 -> 300-tiles track
# Epoch: 46
# Policy Aggregation	mean: 579.82	variance: 252.23
# Track generation: 1134..1427 -> 293-tiles track
# Epoch: 47
# Policy Aggregation	mean: 580.76	variance: 249.62
# Track generation: 976..1228 -> 252-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1029..1296 -> 267-tiles track
# Epoch: 48
# Policy Aggregation	mean: 586.14	variance: 249.74
# Track generation: 1220..1529 -> 309-tiles track
# Epoch: 49
# Policy Aggregation	mean: 580.61	variance: 250.13
# Track generation: 1102..1387 -> 285-tiles track
# Epoch: 50
# Policy Aggregation	mean: 578.61	variance: 248.01
# epoch 2
# Track generation: 1267..1588 -> 321-tiles track
# score: 899.8249999999853
# Track generation: 1148..1439 -> 291-tiles track
# score: 1024.8999999999855
# Track generation: 1092..1369 -> 277-tiles track
# score: 912.607246376804
# Track generation: 1333..1672 -> 339-tiles track
# score: 985.2071005916948
# Track generation: 1027..1288 -> 261-tiles track
# score: 908.8692307692168
# Track generation: 1042..1306 -> 264-tiles track
# score: 911.8908745246979
# Track generation: 1163..1458 -> 295-tiles track
# score: 315.1401360544194
# Track generation: 1099..1378 -> 279-tiles track
# score: 899.1172661870341
# Track generation: 1009..1272 -> 263-tiles track
# score: 1034.6999999999941
# Track generation: 1214..1521 -> 307-tiles track
# score: 1021.9999999999811
# Track generation: 1106..1387 -> 281-tiles track
# score: 1031.0999999999867
# Track generation: 1148..1441 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1256..1574 -> 318-tiles track
# score: 856.9722397476211
# Track generation: 1052..1319 -> 267-tiles track
# score: 913.7718045112628
# Track generation: 1198..1501 -> 303-tiles track
# score: 908.1887417218439
# Track generation: 1225..1537 -> 312-tiles track
# score: 895.7228295819779
# Track generation: 1008..1264 -> 256-tiles track
# score: 1038.7999999999865
# Track generation: 1286..1611 -> 325-tiles track
# score: 875.6222222222019
# Track generation: 1187..1488 -> 301-tiles track
# score: 1031.899999999994
# Track generation: 1128..1414 -> 286-tiles track
# score: 903.6561403508614
# Track generation: 1140..1429 -> 289-tiles track
# score: 892.3222222222041
# Track generation: 1280..1604 -> 324-tiles track
# score: 886.9241486067996
# Track generation: 1198..1501 -> 303-tiles track
# score: 901.2549668874072
# Track generation: 1091..1368 -> 277-tiles track
# score: 1033.399999999994
# Track generation: 1076..1349 -> 273-tiles track
# score: 898.5647058823365
# Track generation: 1130..1416 -> 286-tiles track
# score: 884.3035087719144
# Track generation: 1160..1454 -> 294-tiles track
# score: 910.261092150153
# Track generation: 1055..1323 -> 268-tiles track
# score: 907.4734082396909
# Track generation: 974..1222 -> 248-tiles track
# score: 441.98137651821327
# Track generation: 1484..1859 -> 375-tiles track
# score: 1001.2999999999794
# Track generation: 1099..1378 -> 279-tiles track
# score: 903.5143884891926
# Track generation: 1195..1498 -> 303-tiles track
# score: 896.3437086092613
# Track generation: 1193..1495 -> 302-tiles track
# score: 904.4554817275646
# Track generation: 1108..1393 -> 285-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1116..1399 -> 283-tiles track
# score: 913.4617021276492
# Track generation: 1192..1494 -> 302-tiles track
# score: 900.888704318928
# Track generation: 1184..1484 -> 300-tiles track
# score: 1026.7999999999834
# Track generation: 1143..1433 -> 290-tiles track
# score: 1027.5999999999935
# Track generation: 1172..1469 -> 297-tiles track
# score: 903.30810810809
# Track generation: 1147..1438 -> 291-tiles track
# score: 1029.8999999999867
# Track generation: 1208..1514 -> 306-tiles track
# score: 867.9770491803139
# Track generation: 1172..1469 -> 297-tiles track
# score: 1029.0999999999838
# Track generation: 1226..1537 -> 311-tiles track
# score: 1024.4999999999932
# Track generation: 1268..1589 -> 321-tiles track
# score: 1019.5999999999879
# Track generation: 1096..1374 -> 278-tiles track
# score: 913.1797833934946
# Track generation: 1213..1530 -> 317-tiles track
# score: 1017.7999999999936
# Track generation: 1198..1504 -> 306-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1155..1448 -> 293-tiles track
# score: 903.7013698629963
# Track generation: 1284..1609 -> 325-tiles track
# score: 1021.1999999999832
# Track generation: 1081..1355 -> 274-tiles track
# score: 908.3479853479755
# Track generation: 1170..1466 -> 296-tiles track
# score: 897.7508474576127
# Track generation: 1036..1279 -> 243-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1200..1504 -> 304-tiles track
# score: 1023.6999999999923
# Track generation: 1075..1348 -> 273-tiles track
# score: 1030.1999999999848
# Track generation: 1117..1408 -> 291-tiles track
# score: 896.6103448275712
# Track generation: 1225..1515 -> 290-tiles track
# score: 906.7795847750767
# Track generation: 949..1199 -> 250-tiles track
# score: 893.2714859437656
# Track generation: 1217..1525 -> 308-tiles track
# score: 1024.3999999999833
# Track generation: 1116..1400 -> 284-tiles track
# score: 1028.399999999987
# Track generation: 1123..1408 -> 285-tiles track
# score: 901.5943661971656
# Track generation: 1176..1474 -> 298-tiles track
# score: 901.7979797979642
# Track generation: 1208..1514 -> 306-tiles track
# score: 893.4491803278565
# Track generation: 1018..1284 -> 266-tiles track
# score: 1032.7999999999936
# Track generation: 1141..1438 -> 297-tiles track
# score: 1023.7999999999837
# Track generation: 1146..1446 -> 300-tiles track
# score: 905.2555183946296
# Track generation: 1223..1535 -> 312-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1352..1694 -> 342-tiles track
# score: 896.234897360681
# Track generation: 1021..1290 -> 269-tiles track
# score: 1031.9999999999882
# Track generation: 1197..1508 -> 311-tiles track
# score: 901.1483870967645
# Track generation: 1328..1665 -> 337-tiles track
# score: 979.1666666666545
# Track generation: 983..1237 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1121..1412 -> 291-tiles track
# score: 1025.1999999999866
# Track generation: 1251..1568 -> 317-tiles track
# score: 894.2772151898639
# Track generation: 1224..1534 -> 310-tiles track
# score: 896.3550161812132
# Track generation: 1193..1495 -> 302-tiles track
# score: 898.5887043189275
# Track generation: 1156..1449 -> 293-tiles track
# score: 408.204794520544
# Track generation: 1229..1540 -> 311-tiles track
# score: 901.3483870967635
# Track generation: 1124..1414 -> 290-tiles track
# score: 822.1039792387469
# Track generation: 1315..1648 -> 333-tiles track
# score: 1011.1999999999878
# Track generation: 1032..1294 -> 262-tiles track
# score: 902.5114942528664
# Track generation: 1097..1379 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1099..1381 -> 282-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1188..1489 -> 301-tiles track
# score: 903.5999999999898
# Track generation: 1112..1394 -> 282-tiles track
# score: 911.9238434163587
# Track generation: 1183..1483 -> 300-tiles track
# score: 1024.5999999999826
# Track generation: 1255..1573 -> 318-tiles track
# score: 1020.6999999999899
# Track generation: 1077..1354 -> 277-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1228..1539 -> 311-tiles track
# score: 890.3193548387001
# Track generation: 1000..1258 -> 258-tiles track
# score: 1038.5999999999938
# Track generation: 1134..1422 -> 288-tiles track
# score: 903.2783972125305
# Track generation: 1043..1308 -> 265-tiles track
# score: 1037.599999999988
# Track generation: 1169..1465 -> 296-tiles track
# score: 912.9101694915114
# Track generation: 983..1233 -> 250-tiles track
# score: 900.6875502007935
# Track generation: 1299..1628 -> 329-tiles track
# score: 249.62926829268469
# Track generation: 1195..1505 -> 310-tiles track
# score: 1018.6999999999864
# Track generation: 1040..1313 -> 273-tiles track
# score: 1034.2999999999865
# Track generation: 1042..1313 -> 271-tiles track
# score: 1031.9999999999886
# Track generation: 1035..1298 -> 263-tiles track
# score: 1037.4999999999936
# Track generation: 1088..1364 -> 276-tiles track
# score: 1032.1999999999875
# Track generation: 1182..1490 -> 308-tiles track
# score: 1020.6999999999825
# Track generation: 1232..1543 -> 311-tiles track
# score: 961.2903225806324
# Track generation: 1261..1580 -> 319-tiles track
# score: 893.4767295597281
# Track generation: 1227..1544 -> 317-tiles track
# score: 1011.0999999999921
# Track generation: 1125..1410 -> 285-tiles track
# score: 756.6070422535062
# Track generation: 1317..1650 -> 333-tiles track
# score: 881.6156626505895
# Track generation: 1140..1429 -> 289-tiles track
# score: 1028.9999999999836
# Track generation: 1228..1539 -> 311-tiles track
# score: 900.3483870967633
# Track generation: 1134..1421 -> 287-tiles track
# score: 1024.9999999999864
# Track generation: 1225..1536 -> 311-tiles track
# score: 1021.9999999999926
# Dataset size: 9529
# [001/050] 3.11 sec(s) Train Loss: 0.000396 | Val loss: 0.000185
# [002/050] 2.99 sec(s) Train Loss: 0.000139 | Val loss: 0.000096
# [003/050] 2.95 sec(s) Train Loss: 0.000083 | Val loss: 0.000069
# [004/050] 2.99 sec(s) Train Loss: 0.000060 | Val loss: 0.000063
# [005/050] 3.11 sec(s) Train Loss: 0.000054 | Val loss: 0.000048
# [006/050] 2.89 sec(s) Train Loss: 0.000045 | Val loss: 0.000043
# [007/050] 2.84 sec(s) Train Loss: 0.000044 | Val loss: 0.000043
# [008/050] 2.69 sec(s) Train Loss: 0.000042 | Val loss: 0.000040
# [009/050] 2.83 sec(s) Train Loss: 0.000040 | Val loss: 0.000041
# [010/050] 3.03 sec(s) Train Loss: 0.000041 | Val loss: 0.000040
# [011/050] 3.03 sec(s) Train Loss: 0.000037 | Val loss: 0.000038
# [012/050] 2.72 sec(s) Train Loss: 0.000036 | Val loss: 0.000040
# [013/050] 2.95 sec(s) Train Loss: 0.000037 | Val loss: 0.000038
# [014/050] 2.83 sec(s) Train Loss: 0.000036 | Val loss: 0.000036
# [015/050] 2.94 sec(s) Train Loss: 0.000034 | Val loss: 0.000037
# [016/050] 2.86 sec(s) Train Loss: 0.000033 | Val loss: 0.000034
# [017/050] 3.04 sec(s) Train Loss: 0.000034 | Val loss: 0.000033
# [018/050] 3.29 sec(s) Train Loss: 0.000033 | Val loss: 0.000033
# [019/050] 3.04 sec(s) Train Loss: 0.000032 | Val loss: 0.000037
# [020/050] 3.00 sec(s) Train Loss: 0.000032 | Val loss: 0.000032
# [021/050] 3.40 sec(s) Train Loss: 0.000032 | Val loss: 0.000033
# [022/050] 2.92 sec(s) Train Loss: 0.000030 | Val loss: 0.000030
# [023/050] 2.76 sec(s) Train Loss: 0.000031 | Val loss: 0.000033
# [024/050] 2.74 sec(s) Train Loss: 0.000030 | Val loss: 0.000032
# [025/050] 2.78 sec(s) Train Loss: 0.000029 | Val loss: 0.000030
# [026/050] 2.80 sec(s) Train Loss: 0.000029 | Val loss: 0.000032
# [027/050] 2.73 sec(s) Train Loss: 0.000029 | Val loss: 0.000030
# [028/050] 2.75 sec(s) Train Loss: 0.000028 | Val loss: 0.000029
# [029/050] 2.87 sec(s) Train Loss: 0.000027 | Val loss: 0.000030
# [030/050] 3.07 sec(s) Train Loss: 0.000027 | Val loss: 0.000031
# [031/050] 3.07 sec(s) Train Loss: 0.000027 | Val loss: 0.000029
# [032/050] 3.04 sec(s) Train Loss: 0.000027 | Val loss: 0.000029
# [033/050] 2.80 sec(s) Train Loss: 0.000026 | Val loss: 0.000032
# [034/050] 2.92 sec(s) Train Loss: 0.000026 | Val loss: 0.000031
# [035/050] 3.03 sec(s) Train Loss: 0.000027 | Val loss: 0.000031
# [036/050] 3.10 sec(s) Train Loss: 0.000027 | Val loss: 0.000030
# [037/050] 3.02 sec(s) Train Loss: 0.000025 | Val loss: 0.000029
# [038/050] 2.83 sec(s) Train Loss: 0.000026 | Val loss: 0.000029
# [039/050] 2.97 sec(s) Train Loss: 0.000027 | Val loss: 0.000029
# [040/050] 3.29 sec(s) Train Loss: 0.000026 | Val loss: 0.000029
# [041/050] 3.08 sec(s) Train Loss: 0.000024 | Val loss: 0.000030
# [042/050] 2.77 sec(s) Train Loss: 0.000024 | Val loss: 0.000028
# [043/050] 2.76 sec(s) Train Loss: 0.000024 | Val loss: 0.000029
# [044/050] 2.80 sec(s) Train Loss: 0.000023 | Val loss: 0.000028
# [045/050] 2.76 sec(s) Train Loss: 0.000024 | Val loss: 0.000028
# [046/050] 2.70 sec(s) Train Loss: 0.000025 | Val loss: 0.000028
# [047/050] 2.74 sec(s) Train Loss: 0.000023 | Val loss: 0.000028
# [048/050] 2.72 sec(s) Train Loss: 0.000023 | Val loss: 0.000028
# [049/050] 2.75 sec(s) Train Loss: 0.000023 | Val loss: 0.000027
# [050/050] 2.70 sec(s) Train Loss: 0.000023 | Val loss: 0.000030
# Track generation: 995..1251 -> 256-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1154..1450 -> 296-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1252..1569 -> 317-tiles track
# Epoch: 1
# Policy Aggregation	mean: 671.20	variance: 0.00
# Track generation: 1221..1530 -> 309-tiles track
# Epoch: 2
# Policy Aggregation	mean: 500.74	variance: 170.46
# Track generation: 1208..1515 -> 307-tiles track
# Epoch: 3
# Policy Aggregation	mean: 673.76	variance: 281.50
# Track generation: 1237..1560 -> 323-tiles track
# Epoch: 4
# Policy Aggregation	mean: 621.48	variance: 260.06
# Track generation: 1287..1613 -> 326-tiles track
# Epoch: 5
# Policy Aggregation	mean: 698.44	variance: 278.93
# Track generation: 1131..1418 -> 287-tiles track
# Epoch: 6
# Policy Aggregation	mean: 709.81	variance: 255.89
# Track generation: 1256..1574 -> 318-tiles track
# Epoch: 7
# Policy Aggregation	mean: 736.15	variance: 245.53
# Track generation: 1141..1431 -> 290-tiles track
# Epoch: 8
# Policy Aggregation	mean: 709.98	variance: 239.89
# Track generation: 1222..1532 -> 310-tiles track
# Epoch: 9
# Policy Aggregation	mean: 727.00	variance: 231.23
# Track generation: 1076..1355 -> 279-tiles track
# Epoch: 10
# Policy Aggregation	mean: 743.99	variance: 225.21
# Track generation: 1054..1325 -> 271-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1154..1454 -> 300-tiles track
# Epoch: 11
# Policy Aggregation	mean: 756.96	variance: 218.61
# Track generation: 1208..1514 -> 306-tiles track
# Epoch: 12
# Policy Aggregation	mean: 767.62	variance: 212.27
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 13
# Policy Aggregation	mean: 776.12	variance: 206.06
# Track generation: 1245..1564 -> 319-tiles track
# Epoch: 14
# Policy Aggregation	mean: 740.87	variance: 235.74
# Track generation: 1047..1313 -> 266-tiles track
# Epoch: 15
# Policy Aggregation	mean: 716.92	variance: 244.75
# Track generation: 1111..1393 -> 282-tiles track
# Epoch: 16
# Policy Aggregation	mean: 726.22	variance: 239.70
# Track generation: 1240..1554 -> 314-tiles track
# Epoch: 17
# Policy Aggregation	mean: 700.89	variance: 253.65
# Track generation: 1207..1513 -> 306-tiles track
# Epoch: 18
# Policy Aggregation	mean: 678.17	variance: 263.71
# Track generation: 1190..1492 -> 302-tiles track
# Epoch: 19
# Policy Aggregation	mean: 692.84	variance: 264.11
# Track generation: 1054..1329 -> 275-tiles track
# Epoch: 20
# Policy Aggregation	mean: 702.81	variance: 261.06
# Track generation: 1005..1262 -> 257-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1082..1348 -> 266-tiles track
# Epoch: 21
# Policy Aggregation	mean: 710.68	variance: 257.19
# Track generation: 911..1145 -> 234-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 22
# Policy Aggregation	mean: 699.29	variance: 256.64
# Track generation: 1197..1500 -> 303-tiles track
# Epoch: 23
# Policy Aggregation	mean: 713.35	variance: 259.51
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 24
# Policy Aggregation	mean: 699.80	variance: 262.22
# Track generation: 1140..1431 -> 291-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1004..1267 -> 263-tiles track
# Epoch: 25
# Policy Aggregation	mean: 706.90	variance: 259.27
# Track generation: 1091..1368 -> 277-tiles track
# Epoch: 26
# Policy Aggregation	mean: 712.98	variance: 256.04
# Track generation: 1216..1524 -> 308-tiles track
# Epoch: 27
# Policy Aggregation	mean: 695.22	variance: 267.07
# Track generation: 1033..1305 -> 272-tiles track
# Epoch: 28
# Policy Aggregation	mean: 702.08	variance: 264.67
# Track generation: 1035..1289 -> 254-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1184..1484 -> 300-tiles track
# Epoch: 29
# Policy Aggregation	mean: 708.96	variance: 262.60
# Track generation: 1107..1388 -> 281-tiles track
# Epoch: 30
# Policy Aggregation	mean: 697.64	variance: 265.29
# Track generation: 1208..1523 -> 315-tiles track
# Epoch: 31
# Policy Aggregation	mean: 706.78	variance: 265.73
# Track generation: 1160..1463 -> 303-tiles track
# Epoch: 32
# Policy Aggregation	mean: 716.53	variance: 267.13
# Track generation: 1201..1505 -> 304-tiles track
# Epoch: 33
# Policy Aggregation	mean: 705.45	variance: 270.42
# Track generation: 1078..1353 -> 275-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1136..1425 -> 289-tiles track
# Epoch: 34
# Policy Aggregation	mean: 692.85	variance: 276.06
# Track generation: 1088..1368 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1091..1368 -> 277-tiles track
# Epoch: 35
# Policy Aggregation	mean: 702.34	variance: 277.65
# Track generation: 1179..1478 -> 299-tiles track
# Epoch: 36
# Policy Aggregation	mean: 707.75	variance: 275.63
# Track generation: 1126..1420 -> 294-tiles track
# Epoch: 37
# Policy Aggregation	mean: 700.76	variance: 275.10
# Track generation: 1095..1381 -> 286-tiles track
# Epoch: 38
# Policy Aggregation	mean: 695.38	variance: 273.42
# Track generation: 1294..1622 -> 328-tiles track
# Epoch: 39
# Policy Aggregation	mean: 700.03	variance: 271.41
# Track generation: 1059..1328 -> 269-tiles track
# Epoch: 40
# Policy Aggregation	mean: 703.54	variance: 268.89
# Track generation: 1423..1783 -> 360-tiles track
# Epoch: 41
# Policy Aggregation	mean: 704.59	variance: 265.67
# Track generation: 1107..1391 -> 284-tiles track
# Epoch: 42
# Policy Aggregation	mean: 695.21	variance: 269.28
# Track generation: 1035..1306 -> 271-tiles track
# Epoch: 43
# Policy Aggregation	mean: 702.98	variance: 270.86
# Track generation: 1235..1548 -> 313-tiles track
# Epoch: 44
# Policy Aggregation	mean: 709.66	variance: 271.32
# Track generation: 1147..1438 -> 291-tiles track
# Epoch: 45
# Policy Aggregation	mean: 701.00	variance: 274.38
# Track generation: 1215..1531 -> 316-tiles track
# Epoch: 46
# Policy Aggregation	mean: 707.77	variance: 275.15
# Track generation: 1116..1399 -> 283-tiles track
# Epoch: 47
# Policy Aggregation	mean: 709.62	variance: 272.50
# Track generation: 1166..1468 -> 302-tiles track
# Epoch: 48
# Policy Aggregation	mean: 713.42	variance: 270.91
# Track generation: 1160..1460 -> 300-tiles track
# Epoch: 49
# Policy Aggregation	mean: 719.64	variance: 271.57
# Track generation: 1169..1465 -> 296-tiles track
# Epoch: 50
# Policy Aggregation	mean: 722.41	variance: 269.53
# epoch 3
# Track generation: 1132..1427 -> 295-tiles track
# score: 892.3904761904679
# Track generation: 1072..1344 -> 272-tiles track
# score: 1029.9999999999932
# Track generation: 1020..1290 -> 270-tiles track
# score: 880.3427509293554
# Track generation: 1057..1325 -> 268-tiles track
# score: 908.6734082396912
# Track generation: 949..1196 -> 247-tiles track
# score: 1041.8999999999983
# Track generation: 1116..1399 -> 283-tiles track
# score: 1031.3999999999915
# Track generation: 1355..1698 -> 343-tiles track
# score: 997.0760233917945
# Track generation: 1191..1493 -> 302-tiles track
# score: 875.855149501651
# Track generation: 1116..1399 -> 283-tiles track
# score: 902.3695035460881
# Track generation: 1136..1424 -> 288-tiles track
# score: 1028.0999999999885
# Track generation: 1195..1498 -> 303-tiles track
# score: 892.1324503311154
# Track generation: 1112..1394 -> 282-tiles track
# score: 1039.6999999999925
# Track generation: 1113..1401 -> 288-tiles track
# score: 1025.7999999999888
# Track generation: 1275..1598 -> 323-tiles track
# score: 1019.599999999984
# Track generation: 1292..1619 -> 327-tiles track
# score: 904.2325153374118
# Track generation: 1116..1399 -> 283-tiles track
# score: 1032.5999999999917
# Track generation: 1036..1305 -> 269-tiles track
# score: 1030.9999999999877
# Track generation: 968..1219 -> 251-tiles track
# score: 886.399999999988
# Track generation: 1179..1478 -> 299-tiles track
# score: 1027.7999999999852
# Track generation: 1340..1679 -> 339-tiles track
# score: 889.6071005916964
# Track generation: 1148..1439 -> 291-tiles track
# score: 903.2551724137761
# Track generation: 976..1230 -> 254-tiles track
# score: 1035.5999999999951
# Track generation: 1137..1430 -> 293-tiles track
# score: 1027.4999999999854
# Track generation: 1283..1608 -> 325-tiles track
# score: 892.6543209876339
# Track generation: 1231..1543 -> 312-tiles track
# score: 907.5691318327827
# Track generation: 1111..1393 -> 282-tiles track
# score: 909.9238434163582
# Track generation: 1059..1336 -> 277-tiles track
# score: 892.3072463768009
# Track generation: 1111..1393 -> 282-tiles track
# score: 1035.4999999999916
# Track generation: 1184..1491 -> 307-tiles track
# score: 901.3320261437698
# Track generation: 1248..1564 -> 316-tiles track
# score: 899.9761904761714
# Track generation: 1145..1445 -> 300-tiles track
# score: 881.6441471571715
# Track generation: 1176..1481 -> 305-tiles track
# score: 1020.3999999999871
# Track generation: 996..1258 -> 262-tiles track
# score: 1035.5999999999963
# Track generation: 1203..1508 -> 305-tiles track
# score: 1024.5999999999867
# Track generation: 1165..1460 -> 295-tiles track
# score: 910.6972789115558
# Track generation: 1035..1298 -> 263-tiles track
# score: 1032.2999999999925
# Track generation: 1244..1559 -> 315-tiles track
# score: 1018.299999999981
# Track generation: 1062..1335 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1045..1310 -> 265-tiles track
# score: 906.5727272727137
# Track generation: 1192..1494 -> 302-tiles track
# score: 1027.5999999999935
# Track generation: 1116..1399 -> 283-tiles track
# score: 911.7078014184285
# Track generation: 1174..1472 -> 298-tiles track
# score: 1025.7999999999852
# Track generation: 1152..1443 -> 291-tiles track
# score: 901.8034482758441
# Track generation: 1220..1529 -> 309-tiles track
# score: 912.1532467532282
# Track generation: 1090..1366 -> 276-tiles track
# score: 899.9818181818033
# Track generation: 1284..1609 -> 325-tiles track
# score: 878.9222222222023
# Track generation: 1128..1420 -> 292-tiles track
# score: 897.5814432989525
# Track generation: 1338..1676 -> 338-tiles track
# score: 889.330563798205
# Track generation: 1108..1389 -> 281-tiles track
# score: 913.6571428571273
# Track generation: 1267..1588 -> 321-tiles track
# score: 887.549999999985
# Track generation: 1136..1424 -> 288-tiles track
# score: 905.9627177700215
# Track generation: 1092..1375 -> 283-tiles track
# score: 900.6156028368684
# Track generation: 1051..1318 -> 267-tiles track
# score: 888.9248120300581
# Track generation: 944..1190 -> 246-tiles track
# score: 1035.9999999999882
# Track generation: 1159..1453 -> 294-tiles track
# score: 1027.2999999999838
# Track generation: 1185..1485 -> 300-tiles track
# score: 1022.3999999999822
# Track generation: 1022..1287 -> 265-tiles track
# score: 1031.3999999999878
# Track generation: 1077..1350 -> 273-tiles track
# score: 898.9176470588058
# Track generation: 1152..1453 -> 301-tiles track
# score: 783.6333333333239
# Track generation: 1306..1646 -> 340-tiles track
# score: 988.2005899704928
# Track generation: 1084..1359 -> 275-tiles track
# score: 1029.399999999985
# Track generation: 1188..1489 -> 301-tiles track
# score: 1019.6999999999912
# Track generation: 1124..1409 -> 285-tiles track
# score: 904.7154929577288
# Track generation: 1335..1673 -> 338-tiles track
# score: 1012.499999999989
# Track generation: 1085..1363 -> 278-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1139..1428 -> 289-tiles track
# score: 900.9388888888703
# Track generation: 965..1217 -> 252-tiles track
# score: 905.1796812748936
# Track generation: 1183..1493 -> 310-tiles track
# score: 1015.0999999999855
# Track generation: 1111..1393 -> 282-tiles track
# score: 1030.2999999999902
# Track generation: 1104..1384 -> 280-tiles track
# score: 1037.299999999991
# Track generation: 1104..1384 -> 280-tiles track
# score: 1031.9999999999895
# Track generation: 1111..1396 -> 285-tiles track
# score: 906.3366197182925
# Track generation: 1276..1605 -> 329-tiles track
# score: 1013.0999999999823
# Track generation: 1156..1449 -> 293-tiles track
# score: 894.7767123287485
# Track generation: 1015..1273 -> 258-tiles track
# score: 905.7536964980454
# Track generation: 1064..1334 -> 270-tiles track
# score: 887.2427509293553
# Track generation: 1165..1460 -> 295-tiles track
# score: 874.9836734693782
# Track generation: 1117..1410 -> 293-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1201..1505 -> 304-tiles track
# score: 880.097359735962
# Track generation: 1115..1399 -> 284-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1189..1490 -> 301-tiles track
# score: 908.6333333333233
# Track generation: 1120..1407 -> 287-tiles track
# score: 858.7524475524314
# Track generation: 1188..1491 -> 303-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1024..1289 -> 265-tiles track
# score: 1036.3999999999887
# Track generation: 1147..1438 -> 291-tiles track
# score: 896.31034482757
# Track generation: 1134..1422 -> 288-tiles track
# score: 894.8783972125286
# Track generation: 1131..1417 -> 286-tiles track
# score: 1033.1999999999869
# Track generation: 1118..1402 -> 284-tiles track
# score: 1030.0999999999872
# Track generation: 1115..1398 -> 283-tiles track
# score: 887.8312056737468
# Track generation: 1107..1388 -> 281-tiles track
# score: 1034.7999999999877
# Track generation: 1065..1341 -> 276-tiles track
# score: 914.727272727258
# Track generation: 1164..1459 -> 295-tiles track
# score: 900.1945578231195
# Track generation: 1152..1444 -> 292-tiles track
# score: 1026.3999999999842
# Track generation: 1145..1435 -> 290-tiles track
# score: 878.4979238754239
# Track generation: 1188..1490 -> 302-tiles track
# score: 416.4607973421851
# Track generation: 1123..1408 -> 285-tiles track
# score: 881.0098591549108
# Track generation: 1140..1429 -> 289-tiles track
# score: 907.1833333333145
# Track generation: 1262..1582 -> 320-tiles track
# score: 884.5564263322667
# Track generation: 1251..1568 -> 317-tiles track
# score: 1011.299999999991
# Track generation: 1209..1524 -> 315-tiles track
# score: 895.2458598725913
# Track generation: 1065..1340 -> 275-tiles track
# score: 1029.0999999999858
# Track generation: 1216..1525 -> 309-tiles track
# score: 644.8857142857034
# Track generation: 1120..1404 -> 284-tiles track
# score: 1025.499999999986
# Track generation: 1168..1464 -> 296-tiles track
# score: 1026.6999999999884
# Track generation: 1158..1452 -> 294-tiles track
# score: 887.4962457337696
# Dataset size: 9734
# [001/050] 3.18 sec(s) Train Loss: 0.000393 | Val loss: 0.000184
# [002/050] 2.80 sec(s) Train Loss: 0.000128 | Val loss: 0.000110
# [003/050] 2.82 sec(s) Train Loss: 0.000088 | Val loss: 0.000087
# [004/050] 2.82 sec(s) Train Loss: 0.000069 | Val loss: 0.000070
# [005/050] 2.82 sec(s) Train Loss: 0.000057 | Val loss: 0.000056
# [006/050] 2.93 sec(s) Train Loss: 0.000048 | Val loss: 0.000054
# [007/050] 2.89 sec(s) Train Loss: 0.000044 | Val loss: 0.000055
# [008/050] 2.92 sec(s) Train Loss: 0.000044 | Val loss: 0.000045
# [009/050] 2.88 sec(s) Train Loss: 0.000041 | Val loss: 0.000042
# [010/050] 2.92 sec(s) Train Loss: 0.000039 | Val loss: 0.000049
# [011/050] 2.90 sec(s) Train Loss: 0.000038 | Val loss: 0.000043
# [012/050] 2.92 sec(s) Train Loss: 0.000035 | Val loss: 0.000039
# [013/050] 2.90 sec(s) Train Loss: 0.000034 | Val loss: 0.000040
# [014/050] 2.96 sec(s) Train Loss: 0.000033 | Val loss: 0.000037
# [015/050] 2.89 sec(s) Train Loss: 0.000032 | Val loss: 0.000034
# [016/050] 2.90 sec(s) Train Loss: 0.000033 | Val loss: 0.000041
# [017/050] 2.90 sec(s) Train Loss: 0.000031 | Val loss: 0.000035
# [018/050] 2.90 sec(s) Train Loss: 0.000032 | Val loss: 0.000035
# [019/050] 2.90 sec(s) Train Loss: 0.000030 | Val loss: 0.000033
# [020/050] 2.92 sec(s) Train Loss: 0.000030 | Val loss: 0.000035
# [021/050] 2.92 sec(s) Train Loss: 0.000030 | Val loss: 0.000034
# [022/050] 2.97 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [023/050] 2.91 sec(s) Train Loss: 0.000030 | Val loss: 0.000034
# [024/050] 2.91 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [025/050] 2.95 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [026/050] 2.90 sec(s) Train Loss: 0.000027 | Val loss: 0.000038
# [027/050] 2.92 sec(s) Train Loss: 0.000027 | Val loss: 0.000035
# [028/050] 2.90 sec(s) Train Loss: 0.000026 | Val loss: 0.000032
# [029/050] 2.90 sec(s) Train Loss: 0.000025 | Val loss: 0.000029
# [030/050] 2.90 sec(s) Train Loss: 0.000026 | Val loss: 0.000034
# [031/050] 2.91 sec(s) Train Loss: 0.000026 | Val loss: 0.000030
# [032/050] 2.89 sec(s) Train Loss: 0.000026 | Val loss: 0.000030
# [033/050] 2.92 sec(s) Train Loss: 0.000025 | Val loss: 0.000030
# [034/050] 2.90 sec(s) Train Loss: 0.000026 | Val loss: 0.000029
# [035/050] 2.93 sec(s) Train Loss: 0.000025 | Val loss: 0.000033
# [036/050] 2.89 sec(s) Train Loss: 0.000025 | Val loss: 0.000029
# [037/050] 2.90 sec(s) Train Loss: 0.000024 | Val loss: 0.000032
# [038/050] 2.86 sec(s) Train Loss: 0.000024 | Val loss: 0.000035
# [039/050] 2.93 sec(s) Train Loss: 0.000025 | Val loss: 0.000027
# [040/050] 2.89 sec(s) Train Loss: 0.000023 | Val loss: 0.000029
# [041/050] 2.90 sec(s) Train Loss: 0.000022 | Val loss: 0.000029
# [042/050] 2.93 sec(s) Train Loss: 0.000022 | Val loss: 0.000029
# [043/050] 2.89 sec(s) Train Loss: 0.000023 | Val loss: 0.000027
# [044/050] 2.92 sec(s) Train Loss: 0.000022 | Val loss: 0.000027
# [045/050] 2.88 sec(s) Train Loss: 0.000022 | Val loss: 0.000027
# [046/050] 2.92 sec(s) Train Loss: 0.000023 | Val loss: 0.000030
# [047/050] 2.87 sec(s) Train Loss: 0.000021 | Val loss: 0.000028
# [048/050] 2.91 sec(s) Train Loss: 0.000021 | Val loss: 0.000033
# [049/050] 2.89 sec(s) Train Loss: 0.000021 | Val loss: 0.000028
# [050/050] 2.91 sec(s) Train Loss: 0.000021 | Val loss: 0.000027
# Track generation: 991..1246 -> 255-tiles track
# Epoch: 1
# Policy Aggregation	mean: 861.28	variance: 0.00
# Track generation: 1209..1516 -> 307-tiles track
# Epoch: 2
# Policy Aggregation	mean: 872.02	variance: 10.74
# Track generation: 1101..1381 -> 280-tiles track
# Epoch: 3
# Policy Aggregation	mean: 868.60	variance: 10.01
# Track generation: 1127..1418 -> 291-tiles track
# Epoch: 4
# Policy Aggregation	mean: 877.62	variance: 17.88
# Track generation: 1148..1439 -> 291-tiles track
# Epoch: 5
# Policy Aggregation	mean: 878.98	variance: 16.22
# Track generation: 1200..1504 -> 304-tiles track
# Epoch: 6
# Policy Aggregation	mean: 884.00	variance: 18.58
# Track generation: 1075..1355 -> 280-tiles track
# Epoch: 7
# Policy Aggregation	mean: 885.98	variance: 17.87
# Track generation: 1112..1394 -> 282-tiles track
# Epoch: 8
# Policy Aggregation	mean: 886.61	variance: 16.80
# Track generation: 972..1224 -> 252-tiles track
# Epoch: 9
# ...
# score: 623.3959016393367
# Track generation: 1156..1449 -> 293-tiles track
# score: 847.2808219177888
# Track generation: 1067..1347 -> 280-tiles track
# score: 913.9784946236457
# Track generation: 1113..1395 -> 282-tiles track
# score: 903.5651245551481
# Track generation: 1199..1503 -> 304-tiles track
# score: 893.8983498349734
# Track generation: 1136..1424 -> 288-tiles track
# score: 911.1156794424943
# Track generation: 1279..1603 -> 324-tiles track
# score: 885.5241486067995
# Track generation: 1134..1422 -> 288-tiles track
# score: 700.484843205565
# Track generation: 1176..1474 -> 298-tiles track
# score: 806.0569023568835
# Track generation: 1117..1408 -> 291-tiles track
# score: 1024.9999999999868
# Track generation: 1136..1424 -> 288-tiles track
# score: 898.1783972125294
# Track generation: 1069..1347 -> 278-tiles track
# score: 864.1483754512557
# Track generation: 1160..1454 -> 294-tiles track
# score: 846.8535836177282
# Track generation: 1061..1337 -> 276-tiles track
# score: 903.0909090908935
# Track generation: 1101..1388 -> 287-tiles track
# score: 904.1104895104735
# Track generation: 1247..1562 -> 315-tiles track
# score: 879.8070063694045
# Track generation: 1061..1334 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1197..1500 -> 303-tiles track
# score: 888.3324503311146
# Track generation: 1277..1600 -> 323-tiles track
# score: 1013.9999999999833
# Track generation: 1150..1448 -> 298-tiles track
# score: 1015.7999999999843
# Track generation: 1228..1539 -> 311-tiles track
# score: 897.1967741935382
# Track generation: 1171..1468 -> 297-tiles track
# score: 619.1324324324228
# Track generation: 1118..1409 -> 291-tiles track
# score: 515.2965517241284
# Track generation: 1188..1489 -> 301-tiles track
# score: 885.766666666655
# Track generation: 1238..1552 -> 314-tiles track
# score: 1012.1999999999879
# Track generation: 1164..1459 -> 295-tiles track
# score: 885.7918367346824
# Track generation: 1116..1399 -> 283-tiles track
# score: 902.0695035460885
# Track generation: 1199..1503 -> 304-tiles track
# score: 880.7970297029593
# Track generation: 1071..1348 -> 277-tiles track
# score: 892.9840579710045
# Track generation: 1147..1438 -> 291-tiles track
# score: 894.91034482757
# Track generation: 1196..1499 -> 303-tiles track
# score: 886.209933774825
# Track generation: 1140..1429 -> 289-tiles track
# score: 900.3111111110916
# Track generation: 1088..1364 -> 276-tiles track
# score: 877.1636363636217
# Track generation: 1024..1284 -> 260-tiles track
# score: 883.0899613899446
# Track generation: 1168..1464 -> 296-tiles track
# score: 886.761016949137
# Track generation: 1007..1271 -> 264-tiles track
# score: 908.3954372623394
# Track generation: 1113..1395 -> 282-tiles track
# score: 712.2007117437643
# Track generation: 1064..1334 -> 270-tiles track
# score: 856.2855018587239
# Track generation: 853..1078 -> 225-tiles track
# score: 914.2428571428426
# Track generation: 1200..1504 -> 304-tiles track
# score: 888.7983498349716
# Track generation: 1055..1328 -> 273-tiles track
# score: 889.4882352941007
# Track generation: 1277..1601 -> 324-tiles track
# score: 990.7120743033926
# Track generation: 1111..1393 -> 282-tiles track
# score: 1028.09999999999
# Track generation: 1091..1368 -> 277-tiles track
# score: 897.7876811594119
# Track generation: 1111..1402 -> 291-tiles track
# score: 889.806896551706
# Track generation: 1059..1334 -> 275-tiles track
# score: 907.0510948904949
# Track generation: 1170..1476 -> 306-tiles track
# score: 479.6475409836023
# Track generation: 1228..1539 -> 311-tiles track
# score: 883.2935483870863
# Track generation: 1297..1625 -> 328-tiles track
# score: 617.7370030581021
# Track generation: 1248..1572 -> 324-tiles track
# score: 886.4201238389973
# Track generation: 1120..1404 -> 284-tiles track
# score: 911.2657243816116
# Track generation: 1151..1445 -> 294-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1367..1713 -> 346-tiles track
# score: 654.1304347825943
# Track generation: 1132..1419 -> 287-tiles track
# score: 1030.8999999999876
# Track generation: 1211..1518 -> 307-tiles track
# score: 771.9091503267795
# Track generation: 1174..1481 -> 307-tiles track
# score: 897.8640522875605
# Track generation: 1252..1569 -> 317-tiles track
# score: 865.7607594936613
# Track generation: 1327..1663 -> 336-tiles track
# score: 882.7895522387877
# Track generation: 1108..1389 -> 281-tiles track
# score: 866.728571428556
# Track generation: 1243..1558 -> 315-tiles track
# score: 888.9764331209989
# Track generation: 1021..1288 -> 267-tiles track
# score: 473.7563909774375
# Track generation: 1066..1344 -> 278-tiles track
# score: 472.85559566786486
# Track generation: 1319..1653 -> 334-tiles track
# score: 984.9849849849643
# Track generation: 1356..1699 -> 343-tiles track
# score: 988.304093567234
# Track generation: 1110..1396 -> 286-tiles track
# score: 396.3964912280656
# Track generation: 1088..1364 -> 276-tiles track
# score: 1027.9999999999873
# Track generation: 1288..1614 -> 326-tiles track
# score: 316.17307692307406
# Track generation: 1277..1601 -> 324-tiles track
# score: 267.4693498452011
# Track generation: 1035..1304 -> 269-tiles track
# score: 799.434328358196
# Track generation: 1103..1392 -> 289-tiles track
# score: 1023.5999999999839
# Track generation: 1212..1519 -> 307-tiles track
# score: 888.9921568627235
# Track generation: 1060..1336 -> 276-tiles track
# score: 889.9090909090762
# Track generation: 1215..1528 -> 313-tiles track
# score: 1011.999999999985
# Track generation: 1092..1372 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1033..1296 -> 263-tiles track
# score: 1030.5999999999924
# Track generation: 985..1242 -> 257-tiles track
# score: 914.9937499999874
# Track generation: 1100..1379 -> 279-tiles track
# score: 889.2230215827175
# Track generation: 1091..1368 -> 277-tiles track
# score: 870.5217391304242
# Track generation: 1060..1329 -> 269-tiles track
# score: 1029.0999999999865
# Track generation: 964..1209 -> 245-tiles track
# score: 402.2163934426139
# Track generation: 1206..1513 -> 307-tiles track
# score: 903.8960784313518
# Track generation: 1083..1358 -> 275-tiles track
# score: 1035.5999999999867
# Track generation: 1141..1430 -> 289-tiles track
# score: 904.2111111110927
# Track generation: 1217..1525 -> 308-tiles track
# score: 1020.0999999999813
# Track generation: 1070..1344 -> 274-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1101..1387 -> 286-tiles track
# score: 860.868421052615
# Track generation: 1164..1459 -> 295-tiles track
# score: 1026.7999999999936
# Track generation: 983..1236 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1060..1329 -> 269-tiles track
# score: 848.7731343283439
# Track generation: 1193..1498 -> 305-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1211..1517 -> 306-tiles track
# score: 1014.5999999999872
# Dataset size: 8365
# [001/050] 2.55 sec(s) Train Loss: 0.000387 | Val loss: 0.000209
# [002/050] 2.53 sec(s) Train Loss: 0.000182 | Val loss: 0.000145
# [003/050] 2.43 sec(s) Train Loss: 0.000108 | Val loss: 0.000095
# [004/050] 2.38 sec(s) Train Loss: 0.000081 | Val loss: 0.000071
# [005/050] 2.36 sec(s) Train Loss: 0.000065 | Val loss: 0.000063
# [006/050] 2.39 sec(s) Train Loss: 0.000058 | Val loss: 0.000056
# [007/050] 2.38 sec(s) Train Loss: 0.000053 | Val loss: 0.000052
# [008/050] 2.38 sec(s) Train Loss: 0.000051 | Val loss: 0.000051
# [009/050] 2.36 sec(s) Train Loss: 0.000049 | Val loss: 0.000046
# [010/050] 2.36 sec(s) Train Loss: 0.000047 | Val loss: 0.000047
# [011/050] 2.38 sec(s) Train Loss: 0.000046 | Val loss: 0.000045
# [012/050] 2.37 sec(s) Train Loss: 0.000044 | Val loss: 0.000044
# [013/050] 2.38 sec(s) Train Loss: 0.000043 | Val loss: 0.000043
# [014/050] 2.37 sec(s) Train Loss: 0.000043 | Val loss: 0.000060
# [015/050] 2.38 sec(s) Train Loss: 0.000046 | Val loss: 0.000043
# [016/050] 2.46 sec(s) Train Loss: 0.000042 | Val loss: 0.000041
# [017/050] 2.47 sec(s) Train Loss: 0.000039 | Val loss: 0.000045
# [018/050] 2.54 sec(s) Train Loss: 0.000039 | Val loss: 0.000047
# [019/050] 2.43 sec(s) Train Loss: 0.000038 | Val loss: 0.000043
# [020/050] 2.49 sec(s) Train Loss: 0.000036 | Val loss: 0.000040
# [021/050] 2.41 sec(s) Train Loss: 0.000037 | Val loss: 0.000037
# [022/050] 2.61 sec(s) Train Loss: 0.000037 | Val loss: 0.000047
# [023/050] 2.54 sec(s) Train Loss: 0.000036 | Val loss: 0.000038
# [024/050] 2.72 sec(s) Train Loss: 0.000035 | Val loss: 0.000036
# [025/050] 2.50 sec(s) Train Loss: 0.000034 | Val loss: 0.000038
# [026/050] 2.45 sec(s) Train Loss: 0.000035 | Val loss: 0.000037
# [027/050] 2.43 sec(s) Train Loss: 0.000033 | Val loss: 0.000042
# [028/050] 2.47 sec(s) Train Loss: 0.000032 | Val loss: 0.000034
# [029/050] 2.61 sec(s) Train Loss: 0.000032 | Val loss: 0.000039
# [030/050] 2.44 sec(s) Train Loss: 0.000032 | Val loss: 0.000037
# [031/050] 2.47 sec(s) Train Loss: 0.000031 | Val loss: 0.000038
# [032/050] 2.49 sec(s) Train Loss: 0.000031 | Val loss: 0.000032
# [033/050] 2.43 sec(s) Train Loss: 0.000032 | Val loss: 0.000035
# [034/050] 2.54 sec(s) Train Loss: 0.000031 | Val loss: 0.000032
# [035/050] 2.62 sec(s) Train Loss: 0.000031 | Val loss: 0.000034
# [036/050] 2.60 sec(s) Train Loss: 0.000030 | Val loss: 0.000038
# [037/050] 2.63 sec(s) Train Loss: 0.000031 | Val loss: 0.000033
# [038/050] 2.42 sec(s) Train Loss: 0.000029 | Val loss: 0.000034
# [039/050] 2.40 sec(s) Train Loss: 0.000029 | Val loss: 0.000042
# [040/050] 2.44 sec(s) Train Loss: 0.000028 | Val loss: 0.000031
# [041/050] 2.44 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [042/050] 2.41 sec(s) Train Loss: 0.000028 | Val loss: 0.000042
# [043/050] 2.47 sec(s) Train Loss: 0.000030 | Val loss: 0.000041
# [044/050] 2.56 sec(s) Train Loss: 0.000029 | Val loss: 0.000032
# [045/050] 2.43 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [046/050] 2.79 sec(s) Train Loss: 0.000028 | Val loss: 0.000032
# [047/050] 2.43 sec(s) Train Loss: 0.000027 | Val loss: 0.000034
# [048/050] 2.40 sec(s) Train Loss: 0.000027 | Val loss: 0.000031
# [049/050] 2.42 sec(s) Train Loss: 0.000026 | Val loss: 0.000031
# [050/050] 2.43 sec(s) Train Loss: 0.000026 | Val loss: 0.000037
# Track generation: 1001..1261 -> 260-tiles track
# Epoch: 1
# Policy Aggregation	mean: 669.09	variance: 0.00
# Track generation: 1126..1411 -> 285-tiles track
# Epoch: 2
# Policy Aggregation	mean: 784.50	variance: 115.41
# Track generation: 980..1233 -> 253-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1127..1413 -> 286-tiles track
# Epoch: 3
# Policy Aggregation	mean: 650.93	variance: 211.10
# Track generation: 1104..1394 -> 290-tiles track
# Epoch: 4
# Policy Aggregation	mean: 712.90	variance: 212.00
# Track generation: 1050..1317 -> 267-tiles track
# Epoch: 5
# Policy Aggregation	mean: 749.67	variance: 203.38
# Track generation: 1148..1439 -> 291-tiles track
# Epoch: 6
# Policy Aggregation	mean: 775.92	variance: 194.71
# Track generation: 1155..1448 -> 293-tiles track
# Epoch: 7
# Policy Aggregation	mean: 811.33	variance: 200.05
# Track generation: 1233..1547 -> 314-tiles track
# Epoch: 8
# Policy Aggregation	mean: 757.89	variance: 234.54
# Track generation: 1219..1538 -> 319-tiles track
# Epoch: 9
# Policy Aggregation	mean: 771.21	variance: 224.31
# Track generation: 1175..1473 -> 298-tiles track
# Epoch: 10
# Policy Aggregation	mean: 796.81	variance: 226.23
# Track generation: 1193..1496 -> 303-tiles track
# Epoch: 11
# Policy Aggregation	mean: 745.03	variance: 270.81
# Track generation: 1071..1343 -> 272-tiles track
# Epoch: 12
# Policy Aggregation	mean: 756.25	variance: 261.94
# Track generation: 1100..1379 -> 279-tiles track
# Epoch: 13
# Policy Aggregation	mean: 745.43	variance: 254.44
# Track generation: 1115..1398 -> 283-tiles track
# Epoch: 14
# Policy Aggregation	mean: 720.64	variance: 260.96
# Track generation: 1141..1437 -> 296-tiles track
# Epoch: 15
# Policy Aggregation	mean: 732.05	variance: 255.70
# Track generation: 1307..1638 -> 331-tiles track
# Epoch: 16
# Policy Aggregation	mean: 749.45	variance: 256.59
# Track generation: 1222..1538 -> 316-tiles track
# Epoch: 17
# Policy Aggregation	mean: 765.18	variance: 256.76
# Track generation: 1199..1503 -> 304-tiles track
# Epoch: 18
# Policy Aggregation	mean: 776.76	variance: 254.06
# Track generation: 1120..1404 -> 284-tiles track
# Epoch: 19
# Policy Aggregation	mean: 754.34	variance: 264.95
# Track generation: 1124..1415 -> 291-tiles track
# Epoch: 20
# Policy Aggregation	mean: 767.68	variance: 264.71
# Track generation: 1140..1429 -> 289-tiles track
# Epoch: 21
# Policy Aggregation	mean: 746.09	variance: 275.78
# Track generation: 1167..1471 -> 304-tiles track
# Epoch: 22
# Policy Aggregation	mean: 739.61	variance: 271.06
# Track generation: 1176..1475 -> 299-tiles track
# Epoch: 23
# Policy Aggregation	mean: 746.11	variance: 266.85
# Track generation: 1041..1312 -> 271-tiles track
# Epoch: 24
# Policy Aggregation	mean: 728.68	variance: 274.29
# Track generation: 1081..1356 -> 275-tiles track
# Epoch: 25
# Policy Aggregation	mean: 735.48	variance: 270.80
# Track generation: 1152..1454 -> 302-tiles track
# Epoch: 26
# Policy Aggregation	mean: 746.53	variance: 271.23
# Track generation: 1173..1470 -> 297-tiles track
# Epoch: 27
# Policy Aggregation	mean: 750.67	variance: 267.00
# Track generation: 1277..1600 -> 323-tiles track
# Epoch: 28
# Policy Aggregation	mean: 755.62	variance: 263.45
# Track generation: 1028..1289 -> 261-tiles track
# Epoch: 29
# Policy Aggregation	mean: 759.43	variance: 259.65
# Track generation: 1127..1413 -> 286-tiles track
# Epoch: 30
# Policy Aggregation	mean: 763.90	variance: 256.42
# Track generation: 1241..1564 -> 323-tiles track
# Epoch: 31
# Policy Aggregation	mean: 770.81	variance: 255.07
# Track generation: 1094..1374 -> 280-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1073..1346 -> 273-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 943..1188 -> 245-tiles track
# Epoch: 32
# Policy Aggregation	mean: 779.15	variance: 255.31
# Track generation: 1027..1291 -> 264-tiles track
# Epoch: 33
# Policy Aggregation	mean: 782.68	variance: 252.21
# Track generation: 1247..1565 -> 318-tiles track
# Epoch: 34
# Policy Aggregation	mean: 784.76	variance: 248.75
# Track generation: 1104..1384 -> 280-tiles track
# Epoch: 35
# Policy Aggregation	mean: 785.74	variance: 245.24
# Track generation: 1084..1359 -> 275-tiles track
# Epoch: 36
# Policy Aggregation	mean: 773.50	variance: 252.42
# Track generation: 1313..1645 -> 332-tiles track
# Epoch: 37
# Policy Aggregation	mean: 775.27	variance: 249.21
# Track generation: 1050..1323 -> 273-tiles track
# Epoch: 38
# Policy Aggregation	mean: 778.28	variance: 246.59
# Track generation: 1204..1509 -> 305-tiles track
# Epoch: 39
# Policy Aggregation	mean: 784.53	variance: 246.43
# Track generation: 1159..1454 -> 295-tiles track
# Epoch: 40
# Policy Aggregation	mean: 786.81	variance: 243.75
# Track generation: 1028..1289 -> 261-tiles track
# retry to generate track (normal if there are not manyinstances of this message)
# Track generation: 1092..1369 -> 277-tiles track
# Epoch: 41
# Policy Aggregation	mean: 777.31	variance: 248.14
# Track generation: 1178..1477 -> 299-tiles track
# Epoch: 42
# Policy Aggregation	mean: 779.77	variance: 245.68
# Track generation: 1032..1298 -> 266-tiles track
# Epoch: 43
# Policy Aggregation	mean: 782.59	variance: 243.49
# Track generation: 1280..1604 -> 324-tiles track
# Epoch: 44
# Policy Aggregation	mean: 771.22	variance: 251.98
# Track generation: 1241..1555 -> 314-tiles track
# Epoch: 45
# Policy Aggregation	mean: 766.46	variance: 251.16
# Track generation: 1155..1448 -> 293-tiles track
# Epoch: 46
# Policy Aggregation	mean: 768.94	variance: 248.97
# Track generation: 1082..1357 -> 275-tiles track
# Epoch: 47
# Policy Aggregation	mean: 760.54	variance: 252.81
# Track generation: 1206..1511 -> 305-tiles track
# Epoch: 48
# Policy Aggregation	mean: 764.57	variance: 251.68
# Track generation: 1053..1320 -> 267-tiles track
# Epoch: 49
# Policy Aggregation	mean: 758.16	variance: 253.03
# Track generation: 1063..1340 -> 277-tiles track
# Epoch: 50
# Policy Aggregation	mean: 760.94	variance: 251.24

# %%
env.close()

# %%
means = np.load('./pagger_model/mean.npy')
stds = np.load('./pagger_model/std.npy')

plt.figure()

l1 = plt.plot(means)[0]
l2 = plt.plot(stds)[0]

plt.grid(axis='y', alpha=0.75)
plt.xlabel('epoch')
plt.title('Policy Aggregation model')
plt.legend(handles=[l1, l2], labels=['mean', 'std'])

plt.show()
